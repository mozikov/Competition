# %% [markdown]
# baseline.ipynp<br>
# .. └ data<br>
# .... ├ train<br>
# .... ├ test<br>
# .... ├ class_id_info.csv<br>
# .... └ sample_submission.csv<br>

# %% [markdown]
# # 사용 패키지

# %%
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
import cv2
import base64
import time
import math
import datetime
import os
from PIL import Image
from io import BytesIO
from tqdm import tqdm
from glob import glob

import torch
import torchvision
import torch.distributed as dist
from torch.utils.data import Dataset
from torchvision import transforms
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection.mask_rcnn import MaskRCNNPredictor
from collections import defaultdict, deque

# %% [markdown]
# # 데이터 로드

# %%
train_files = sorted(glob('./data/train/*'))
test_files = sorted(glob('./data/test/*'))

# %%
train_json_list = []
for file in tqdm(train_files):
    with open(file, "r") as json_file:
        train_json_list.append(json.load(json_file))

test_json_list = []
for file in tqdm(test_files):
    with open(file, "r") as json_file:
        test_json_list.append(json.load(json_file))
# Out:
# 100%|██████████| 62622/62622 [00:59<00:00, 1046.38it/s]
# 100%|██████████| 20874/20874 [00:19<00:00, 1055.48it/s]

# %% [markdown]
# # EDA & 시각화

# %%
label_count = {}
for data in train_json_list:
    for shape in data['shapes']:
        try:
            label_count[shape['label']]+=1
        except:
            label_count[shape['label']]=1

# %%
label_count
# Out:
# {'04_lymph': 12002, '01_ulcer': 38958, '02_mass': 9760, '05_bleeding': 19498}

# %% [markdown]
# 이미지 데이터는 base64형식으로 json파일에 포함되어있습니다.

# %%
plt.figure(figsize=(25,30))
for i in range(30):
    plt.subplot(6,5,i+1)
    # base64 형식을 array로 변환
    img = Image.open(BytesIO(base64.b64decode(train_json_list[i]['imageData'])))
    img = np.array(img, np.uint8)
    title = []
    for shape in train_json_list[i]['shapes']:
        points = np.array(shape['points'], np.int32)
        cv2.polylines(img, [points], True, (0,255,0), 3)
        title.append(shape['label'])
    title = ','.join(title)
    plt.imshow(img)
    plt.subplot(6,5,i+1).set_title(title)
plt.show()

# %% [markdown]
# # 데이터셋
#
# PyTroch https://pytorch.org/tutorials/intermediate/torchvision_tutorial.html 를 활용하여 베이스라인을 작성하였습니다.
#
# 튜토리얼 코드에 맞게 데이터셋을 정의합니다.

# %%
class CustomDataset(Dataset):
    def __init__(self, json_list, mode='train'):
        self.mode = mode
        self.file_name = [json_file['file_name'] for json_file in json_list]
        if mode == 'train':
            self.labels = []
            for data in json_list:
                label = []
                for shapes in data['shapes']:
                    label.append(shapes['label'])
                self.labels.append(label)
            self.points = []
            for data in json_list:
                point = []
                for shapes in data['shapes']:
                    point.append(shapes['points'])
                self.points.append(point)
        self.imgs = [data['imageData'] for data in json_list]
        
        self.widths = [data['imageWidth'] for data in json_list]
        self.heights = [data['imageHeight'] for data in json_list]
        
        self.label_map ={
            '01_ulcer':1, '02_mass':2, '04_lymph':3, '05_bleeding':4
        }
        
        self.transforms = transforms.Compose([
            transforms.ToTensor(),
        ])
        
    def __len__(self):
        return len(self.imgs)
    
    def __getitem__(self, i):
        file_name = self.file_name[i]
        img = Image.open(BytesIO(base64.b64decode(self.imgs[i])))
        img = self.transforms(img)
        
        target = {}
        if self.mode == 'train':
            boxes = []
            for point in self.points[i]:
                x_min = int(np.min(np.array(point)[:,0]))
                x_max = int(np.max(np.array(point)[:,0]))
                y_min = int(np.min(np.array(point)[:,1]))
                y_max = int(np.max(np.array(point)[:,1]))
                boxes.append([x_min, y_min, x_max, y_max])
            boxes = torch.as_tensor(boxes, dtype=torch.float32)

            area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])
            iscrowd = torch.zeros((len(boxes),), dtype=torch.int64)

            label = [self.label_map[label] for label in self.labels[i]]

            masks = []
            for box in boxes:
                mask = np.zeros([int(self.heights[i]), int(self.widths[i])], np.uint8)
                masks.append(cv2.rectangle(mask, (int(box[0]), int(box[1])), (int(box[2]), int(box[3])), 1, -1))

            masks = torch.tensor(masks, dtype=torch.uint8)

            target["boxes"] = boxes
            target["labels"] = torch.tensor(label, dtype=torch.int64)
            target["masks"] = masks
            target["area"] = area
            target["iscrowd"] = iscrowd
        target["image_id"] = torch.tensor([i], dtype=torch.int64)
        if self.mode == 'test':
            target["file_name"] = file_name
        return img, target

# %%
train_dataset = CustomDataset(train_json_list, mode='train')
test_dataset = CustomDataset(test_json_list, mode='test')

# %%
test_dataset = CustomDataset(test_json_list, mode='test')

# %%
def collate_fn(batch):
    return tuple(zip(*batch))

# %%
train_dataset = CustomDataset(train_json_list, mode='train')

torch.manual_seed(1)
indices = torch.randperm(len(train_dataset)).tolist()
train_dataset = torch.utils.data.Subset(train_dataset, indices)

train_data_loader = torch.utils.data.DataLoader(
    train_dataset, batch_size=8, shuffle=True, num_workers=16,
    collate_fn=collate_fn)

# %% [markdown]
# # 모델
#
# Penn-Fudan Database for Pedestrian Detection and Segmentation로 학습된 Mask R-CNN 모델을 finetuning합니다.

# %%
def get_instance_segmentation_model(num_classes):
    # load an instance segmentation model pre-trained on COCO
    model = torchvision.models.detection.maskrcnn_resnet50_fpn(pretrained=True)

    # get the number of input features for the classifier
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    # replace the pre-trained head with a new one
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

    # now get the number of input features for the mask classifier
    in_features_mask = model.roi_heads.mask_predictor.conv5_mask.in_channels
    hidden_layer = 256
    # and replace the mask predictor with a new one
    model.roi_heads.mask_predictor = MaskRCNNPredictor(in_features_mask,
                                                       hidden_layer,
                                                       num_classes)

    return model

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# class 4 + background 1 = 5
num_classes = 5

# get the model using our helper function
model = get_instance_segmentation_model(num_classes)
# move model to the right device
model.to(device)

# construct an optimizer
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.001, momentum=0.9, weight_decay=0.0005)

# and a learning rate scheduler which decreases the learning rate by
# 10x every 3 epochs
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.1)
# Out:
# /Arontier/People/hnefa335/anaconda3/envs/comet/lib/python3.7/site-packages/torch/cuda/__init__.py:80: UserWarning: CUDA initialization: Unexpected error from cudaGetDeviceCount(). Did you run some cuda functions before calling NumCudaDevices() that might have already set an error? Error 804: forward compatibility was attempted on non supported HW (Triggered internally at  ../c10/cuda/CUDAFunctions.cpp:112.)
#   return torch._C._cuda_getDeviceCount() > 0

# %% [markdown]
# # 필요 클래스 및 함수 정의

# %% [markdown]
# ## utils

# %%
class SmoothedValue(object):
    """Track a series of values and provide access to smoothed values over a
    window or the global series average.
    """

    def __init__(self, window_size=20, fmt=None):
        if fmt is None:
            fmt = "{median:.4f} ({global_avg:.4f})"
        self.deque = deque(maxlen=window_size)
        self.total = 0.0
        self.count = 0
        self.fmt = fmt

    def update(self, value, n=1):
        self.deque.append(value)
        self.count += n
        self.total += value * n

    def synchronize_between_processes(self):
        """
        Warning: does not synchronize the deque!
        """
        if not is_dist_avail_and_initialized():
            return
        t = torch.tensor([self.count, self.total], dtype=torch.float64, device='cuda')
        dist.barrier()
        dist.all_reduce(t)
        t = t.tolist()
        self.count = int(t[0])
        self.total = t[1]

    @property
    def median(self):
        d = torch.tensor(list(self.deque))
        return d.median().item()

    @property
    def avg(self):
        d = torch.tensor(list(self.deque), dtype=torch.float32)
        return d.mean().item()

    @property
    def global_avg(self):
        return self.total / self.count

    @property
    def max(self):
        return max(self.deque)

    @property
    def value(self):
        return self.deque[-1]

    def __str__(self):
        return self.fmt.format(
            median=self.median,
            avg=self.avg,
            global_avg=self.global_avg,
            max=self.max,
            value=self.value)
    
class MetricLogger(object):
    def __init__(self, delimiter="\t"):
        self.meters = defaultdict(SmoothedValue)
        self.delimiter = delimiter

    def update(self, **kwargs):
        for k, v in kwargs.items():
            if isinstance(v, torch.Tensor):
                v = v.item()
            assert isinstance(v, (float, int))
            self.meters[k].update(v)

    def __getattr__(self, attr):
        if attr in self.meters:
            return self.meters[attr]
        if attr in self.__dict__:
            return self.__dict__[attr]
        raise AttributeError("'{}' object has no attribute '{}'".format(
            type(self).__name__, attr))

    def __str__(self):
        loss_str = []
        for name, meter in self.meters.items():
            loss_str.append(
                "{}: {}".format(name, str(meter))
            )
        return self.delimiter.join(loss_str)

    def synchronize_between_processes(self):
        for meter in self.meters.values():
            meter.synchronize_between_processes()

    def add_meter(self, name, meter):
        self.meters[name] = meter

    def log_every(self, iterable, print_freq, header=None):
        i = 0
        if not header:
            header = ''
        start_time = time.time()
        end = time.time()
        iter_time = SmoothedValue(fmt='{avg:.4f}')
        data_time = SmoothedValue(fmt='{avg:.4f}')
        space_fmt = ':' + str(len(str(len(iterable)))) + 'd'
        if torch.cuda.is_available():
            log_msg = self.delimiter.join([
                header,
                '[{0' + space_fmt + '}/{1}]',
                'eta: {eta}',
                '{meters}',
                'time: {time}',
                'data: {data}',
                'max mem: {memory:.0f}'
            ])
        else:
            log_msg = self.delimiter.join([
                header,
                '[{0' + space_fmt + '}/{1}]',
                'eta: {eta}',
                '{meters}',
                'time: {time}',
                'data: {data}'
            ])
        MB = 1024.0 * 1024.0
        for obj in iterable:
            data_time.update(time.time() - end)
            yield obj
            iter_time.update(time.time() - end)
            if i % print_freq == 0 or i == len(iterable) - 1:
                eta_seconds = iter_time.global_avg * (len(iterable) - i)
                eta_string = str(datetime.timedelta(seconds=int(eta_seconds)))
                if torch.cuda.is_available():
                    print(log_msg.format(
                        i, len(iterable), eta=eta_string,
                        meters=str(self),
                        time=str(iter_time), data=str(data_time),
                        memory=torch.cuda.max_memory_allocated() / MB))
                else:
                    print(log_msg.format(
                        i, len(iterable), eta=eta_string,
                        meters=str(self),
                        time=str(iter_time), data=str(data_time)))
            i += 1
            end = time.time()
        total_time = time.time() - start_time
        total_time_str = str(datetime.timedelta(seconds=int(total_time)))
        print('{} Total time: {} ({:.4f} s / it)'.format(
            header, total_time_str, total_time / len(iterable)))
        
def warmup_lr_scheduler(optimizer, warmup_iters, warmup_factor):
    def f(x):
        if x >= warmup_iters:
            return 1
        alpha = float(x) / warmup_iters
        return warmup_factor * (1 - alpha) + alpha

    return torch.optim.lr_scheduler.LambdaLR(optimizer, f)

def reduce_dict(input_dict, average=True):
    """
    Args:
        input_dict (dict): all the values will be reduced
        average (bool): whether to do average or sum
    Reduce the values in the dictionary from all processes so that all processes
    have the averaged results. Returns a dict with the same fields as
    input_dict, after reduction.
    """
    world_size = get_world_size()
    if world_size < 2:
        return input_dict
    with torch.no_grad():
        names = []
        values = []
        # sort the keys so that they are consistent across processes
        for k in sorted(input_dict.keys()):
            names.append(k)
            values.append(input_dict[k])
        values = torch.stack(values, dim=0)
        dist.all_reduce(values)
        if average:
            values /= world_size
        reduced_dict = {k: v for k, v in zip(names, values)}
    return reduced_dict

def get_world_size():
    if not is_dist_avail_and_initialized():
        return 1
    return dist.get_world_size()

def is_dist_avail_and_initialized():
    if not dist.is_available():
        return False
    if not dist.is_initialized():
        return False
    return True

# %% [markdown]
# ## engine

# %%
def train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq):
    model.train()
    metric_logger = MetricLogger(delimiter="  ")
    metric_logger.add_meter('lr', SmoothedValue(window_size=1, fmt='{value:.6f}'))
    header = 'Epoch: [{}]'.format(epoch)

    lr_scheduler = None
    if epoch == 0:
        warmup_factor = 1. / 1000
        warmup_iters = min(1000, len(data_loader) - 1)

        lr_scheduler = warmup_lr_scheduler(optimizer, warmup_iters, warmup_factor)

    for images, targets in metric_logger.log_every(data_loader, print_freq, header):
        images = list(image.to(device) for image in images)
        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

        loss_dict = model(images, targets)

        losses = sum(loss for loss in loss_dict.values())

        # reduce losses over all GPUs for logging purposes
        loss_dict_reduced = reduce_dict(loss_dict)
        losses_reduced = sum(loss for loss in loss_dict_reduced.values())

        loss_value = losses_reduced.item()

        if not math.isfinite(loss_value):
            print("Loss is {}, stopping training".format(loss_value))
            print(loss_dict_reduced)
            sys.exit(1)

        optimizer.zero_grad()
        losses.backward()
        optimizer.step()

        if lr_scheduler is not None:
            lr_scheduler.step()

        metric_logger.update(loss=losses_reduced, **loss_dict_reduced)
        metric_logger.update(lr=optimizer.param_groups[0]["lr"])

    return metric_logger

def _get_iou_types(model):
    model_without_ddp = model
    if isinstance(model, torch.nn.parallel.DistributedDataParallel):
        model_without_ddp = model.module
    iou_types = ["bbox"]
    if isinstance(model_without_ddp, torchvision.models.detection.MaskRCNN):
        iou_types.append("segm")
    if isinstance(model_without_ddp, torchvision.models.detection.KeypointRCNN):
        iou_types.append("keypoints")
    return iou_types

# %% [markdown]
# # 학습
# 약 10GB의 GPU 메모리가 필요합니다.
#
# 학습은 1epoch만 진행하였습니다.

# %%
# let's train it for 10 epochs
from torch.optim.lr_scheduler import StepLR
num_epochs = 1

for epoch in range(num_epochs):
    # train for one epoch, printing every 10 iterations
    train_one_epoch(model, optimizer, train_data_loader, device, epoch, print_freq=100)
    # update the learning rate
    lr_scheduler.step()
    # evaluate on the test dataset
# Out:
# /home/dacon/anaconda3/envs/eunil_py38/lib/python3.8/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Epoch: [0]  [   0/7828]  eta: 6:00:59  lr: 0.000002  loss: 2.9400 (2.9400)  loss_classifier: 1.3833 (1.3833)  loss_box_reg: 0.0798 (0.0798)  loss_mask: 1.3434 (1.3434)  loss_objectness: 0.1235 (0.1235)  loss_rpn_box_reg: 0.0099 (0.0099)  time: 2.7670  data: 2.3027  max mem: 5803
# Epoch: [0]  [ 100/7828]  eta: 0:56:34  lr: 0.000102  loss: 0.8794 (1.5439)  loss_classifier: 0.1613 (0.4815)  loss_box_reg: 0.1086 (0.0950)  loss_mask: 0.5570 (0.8581)  loss_objectness: 0.0523 (0.1009)  loss_rpn_box_reg: 0.0072 (0.0084)  time: 0.4213  data: 0.0198  max mem: 6079
# Epoch: [0]  [ 200/7828]  eta: 0:54:41  lr: 0.000202  loss: 0.7780 (1.1760)  loss_classifier: 0.1729 (0.3222)  loss_box_reg: 0.1246 (0.1029)  loss_mask: 0.4266 (0.6705)  loss_objectness: 0.0312 (0.0729)  loss_rpn_box_reg: 0.0065 (0.0074)  time: 0.4227  data: 0.0203  max mem: 6079
# Epoch: [0]  [ 300/7828]  eta: 0:53:35  lr: 0.000302  loss: 0.7371 (1.0367)  loss_classifier: 0.1728 (0.2720)  loss_box_reg: 0.1426 (0.1117)  loss_mask: 0.3917 (0.5857)  loss_objectness: 0.0226 (0.0601)  loss_rpn_box_reg: 0.0058 (0.0071)  time: 0.4234  data: 0.0191  max mem: 6079
# Epoch: [0]  [ 400/7828]  eta: 0:52:46  lr: 0.000402  loss: 0.7253 (0.9633)  loss_classifier: 0.1801 (0.2486)  loss_box_reg: 0.1580 (0.1212)  loss_mask: 0.3677 (0.5356)  loss_objectness: 0.0191 (0.0512)  loss_rpn_box_reg: 0.0057 (0.0068)  time: 0.4280  data: 0.0204  max mem: 6079
# Epoch: [0]  [ 500/7828]  eta: 0:52:01  lr: 0.000501  loss: 0.6999 (0.9140)  loss_classifier: 0.1629 (0.2325)  loss_box_reg: 0.1429 (0.1270)  loss_mask: 0.3647 (0.5026)  loss_objectness: 0.0184 (0.0453)  loss_rpn_box_reg: 0.0056 (0.0066)  time: 0.4250  data: 0.0198  max mem: 6079
# Epoch: [0]  [ 600/7828]  eta: 0:51:17  lr: 0.000601  loss: 0.6624 (0.8775)  loss_classifier: 0.1561 (0.2211)  loss_box_reg: 0.1398 (0.1306)  loss_mask: 0.3328 (0.4782)  loss_objectness: 0.0163 (0.0412)  loss_rpn_box_reg: 0.0042 (0.0063)  time: 0.4237  data: 0.0184  max mem: 6079
# Epoch: [0]  [ 700/7828]  eta: 0:50:34  lr: 0.000701  loss: 0.6383 (0.8473)  loss_classifier: 0.1452 (0.2113)  loss_box_reg: 0.1292 (0.1319)  loss_mask: 0.3437 (0.4599)  loss_objectness: 0.0141 (0.0380)  loss_rpn_box_reg: 0.0043 (0.0062)  time: 0.4258  data: 0.0189  max mem: 6079
# Epoch: [0]  [ 800/7828]  eta: 0:49:53  lr: 0.000801  loss: 0.6125 (0.8215)  loss_classifier: 0.1356 (0.2032)  loss_box_reg: 0.1278 (0.1323)  loss_mask: 0.3260 (0.4448)  loss_objectness: 0.0145 (0.0353)  loss_rpn_box_reg: 0.0039 (0.0060)  time: 0.4242  data: 0.0177  max mem: 6079
# Epoch: [0]  [ 900/7828]  eta: 0:49:11  lr: 0.000901  loss: 0.6513 (0.7998)  loss_classifier: 0.1493 (0.1961)  loss_box_reg: 0.1382 (0.1324)  loss_mask: 0.3408 (0.4323)  loss_objectness: 0.0139 (0.0331)  loss_rpn_box_reg: 0.0045 (0.0058)  time: 0.4269  data: 0.0186  max mem: 6079
# Epoch: [0]  [1000/7828]  eta: 0:48:29  lr: 0.001000  loss: 0.6058 (0.7814)  loss_classifier: 0.1209 (0.1902)  loss_box_reg: 0.1313 (0.1321)  loss_mask: 0.3247 (0.4219)  loss_objectness: 0.0134 (0.0315)  loss_rpn_box_reg: 0.0041 (0.0057)  time: 0.4298  data: 0.0196  max mem: 6079
# Epoch: [0]  [1100/7828]  eta: 0:47:47  lr: 0.001000  loss: 0.6047 (0.7642)  loss_classifier: 0.1290 (0.1846)  loss_box_reg: 0.1271 (0.1312)  loss_mask: 0.3195 (0.4128)  loss_objectness: 0.0144 (0.0300)  loss_rpn_box_reg: 0.0036 (0.0056)  time: 0.4302  data: 0.0211  max mem: 6079
# Epoch: [0]  [1200/7828]  eta: 0:47:05  lr: 0.001000  loss: 0.5418 (0.7487)  loss_classifier: 0.1092 (0.1797)  loss_box_reg: 0.1125 (0.1305)  loss_mask: 0.2891 (0.4045)  loss_objectness: 0.0080 (0.0287)  loss_rpn_box_reg: 0.0032 (0.0055)  time: 0.4261  data: 0.0178  max mem: 6079
# Epoch: [0]  [1300/7828]  eta: 0:46:24  lr: 0.001000  loss: 0.5719 (0.7360)  loss_classifier: 0.1136 (0.1754)  loss_box_reg: 0.1200 (0.1298)  loss_mask: 0.3234 (0.3977)  loss_objectness: 0.0116 (0.0276)  loss_rpn_box_reg: 0.0046 (0.0054)  time: 0.4298  data: 0.0204  max mem: 6079
# Epoch: [0]  [1400/7828]  eta: 0:45:42  lr: 0.001000  loss: 0.5782 (0.7243)  loss_classifier: 0.1104 (0.1715)  loss_box_reg: 0.1258 (0.1295)  loss_mask: 0.3040 (0.3914)  loss_objectness: 0.0111 (0.0265)  loss_rpn_box_reg: 0.0038 (0.0053)  time: 0.4318  data: 0.0206  max mem: 6079
# Epoch: [0]  [1500/7828]  eta: 0:45:01  lr: 0.001000  loss: 0.5835 (0.7138)  loss_classifier: 0.1283 (0.1681)  loss_box_reg: 0.1190 (0.1289)  loss_mask: 0.3119 (0.3859)  loss_objectness: 0.0104 (0.0257)  loss_rpn_box_reg: 0.0040 (0.0053)  time: 0.4297  data: 0.0195  max mem: 6079
# Epoch: [0]  [1600/7828]  eta: 0:44:19  lr: 0.001000  loss: 0.5552 (0.7035)  loss_classifier: 0.1126 (0.1646)  loss_box_reg: 0.1180 (0.1283)  loss_mask: 0.3031 (0.3805)  loss_objectness: 0.0125 (0.0250)  loss_rpn_box_reg: 0.0041 (0.0052)  time: 0.4282  data: 0.0189  max mem: 6079
# Epoch: [0]  [1700/7828]  eta: 0:43:37  lr: 0.001000  loss: 0.5372 (0.6941)  loss_classifier: 0.1150 (0.1616)  loss_box_reg: 0.1231 (0.1276)  loss_mask: 0.2967 (0.3755)  loss_objectness: 0.0124 (0.0242)  loss_rpn_box_reg: 0.0037 (0.0051)  time: 0.4286  data: 0.0187  max mem: 6079
# Epoch: [0]  [1800/7828]  eta: 0:42:55  lr: 0.001000  loss: 0.5470 (0.6864)  loss_classifier: 0.1126 (0.1592)  loss_box_reg: 0.1082 (0.1272)  loss_mask: 0.3093 (0.3714)  loss_objectness: 0.0090 (0.0236)  loss_rpn_box_reg: 0.0033 (0.0051)  time: 0.4267  data: 0.0181  max mem: 6079
# Epoch: [0]  [1900/7828]  eta: 0:42:13  lr: 0.001000  loss: 0.5442 (0.6789)  loss_classifier: 0.1136 (0.1569)  loss_box_reg: 0.1067 (0.1267)  loss_mask: 0.2888 (0.3673)  loss_objectness: 0.0128 (0.0230)  loss_rpn_box_reg: 0.0031 (0.0050)  time: 0.4273  data: 0.0186  max mem: 6079
# Epoch: [0]  [2000/7828]  eta: 0:41:31  lr: 0.001000  loss: 0.5242 (0.6728)  loss_classifier: 0.1015 (0.1550)  loss_box_reg: 0.1150 (0.1265)  loss_mask: 0.2909 (0.3639)  loss_objectness: 0.0079 (0.0224)  loss_rpn_box_reg: 0.0034 (0.0050)  time: 0.4291  data: 0.0195  max mem: 6079
# Epoch: [0]  [2100/7828]  eta: 0:40:49  lr: 0.001000  loss: 0.5327 (0.6666)  loss_classifier: 0.1114 (0.1529)  loss_box_reg: 0.1148 (0.1261)  loss_mask: 0.2979 (0.3606)  loss_objectness: 0.0111 (0.0220)  loss_rpn_box_reg: 0.0037 (0.0049)  time: 0.4282  data: 0.0185  max mem: 6079
# Epoch: [0]  [2200/7828]  eta: 0:40:07  lr: 0.001000  loss: 0.5092 (0.6607)  loss_classifier: 0.1081 (0.1510)  loss_box_reg: 0.1111 (0.1258)  loss_mask: 0.2859 (0.3575)  loss_objectness: 0.0097 (0.0215)  loss_rpn_box_reg: 0.0029 (0.0049)  time: 0.4301  data: 0.0197  max mem: 6079
# Epoch: [0]  [2300/7828]  eta: 0:39:24  lr: 0.001000  loss: 0.5199 (0.6554)  loss_classifier: 0.1062 (0.1493)  loss_box_reg: 0.1136 (0.1255)  loss_mask: 0.2900 (0.3547)  loss_objectness: 0.0114 (0.0210)  loss_rpn_box_reg: 0.0041 (0.0049)  time: 0.4286  data: 0.0186  max mem: 6079
# Epoch: [0]  [2400/7828]  eta: 0:38:42  lr: 0.001000  loss: 0.5317 (0.6501)  loss_classifier: 0.1105 (0.1476)  loss_box_reg: 0.1140 (0.1250)  loss_mask: 0.2934 (0.3519)  loss_objectness: 0.0106 (0.0207)  loss_rpn_box_reg: 0.0034 (0.0048)  time: 0.4258  data: 0.0172  max mem: 6079
# Epoch: [0]  [2500/7828]  eta: 0:37:59  lr: 0.001000  loss: 0.5213 (0.6455)  loss_classifier: 0.1047 (0.1461)  loss_box_reg: 0.1085 (0.1248)  loss_mask: 0.2822 (0.3494)  loss_objectness: 0.0091 (0.0203)  loss_rpn_box_reg: 0.0032 (0.0048)  time: 0.4271  data: 0.0180  max mem: 6079
# Epoch: [0]  [2600/7828]  eta: 0:37:17  lr: 0.001000  loss: 0.5085 (0.6411)  loss_classifier: 0.1009 (0.1448)  loss_box_reg: 0.1168 (0.1246)  loss_mask: 0.2837 (0.3470)  loss_objectness: 0.0075 (0.0200)  loss_rpn_box_reg: 0.0034 (0.0048)  time: 0.4284  data: 0.0179  max mem: 6079
# Epoch: [0]  [2700/7828]  eta: 0:36:34  lr: 0.001000  loss: 0.5620 (0.6368)  loss_classifier: 0.1160 (0.1433)  loss_box_reg: 0.1283 (0.1244)  loss_mask: 0.2815 (0.3447)  loss_objectness: 0.0133 (0.0196)  loss_rpn_box_reg: 0.0043 (0.0047)  time: 0.4280  data: 0.0164  max mem: 6079
# Epoch: [0]  [2800/7828]  eta: 0:35:52  lr: 0.001000  loss: 0.5223 (0.6331)  loss_classifier: 0.1067 (0.1422)  loss_box_reg: 0.1146 (0.1242)  loss_mask: 0.2791 (0.3427)  loss_objectness: 0.0101 (0.0193)  loss_rpn_box_reg: 0.0035 (0.0047)  time: 0.4295  data: 0.0181  max mem: 6079
# Epoch: [0]  [2900/7828]  eta: 0:35:09  lr: 0.001000  loss: 0.5297 (0.6291)  loss_classifier: 0.1025 (0.1409)  loss_box_reg: 0.1211 (0.1239)  loss_mask: 0.2824 (0.3406)  loss_objectness: 0.0076 (0.0190)  loss_rpn_box_reg: 0.0037 (0.0047)  time: 0.4293  data: 0.0183  max mem: 6079
# Epoch: [0]  [3000/7828]  eta: 0:34:27  lr: 0.001000  loss: 0.5031 (0.6254)  loss_classifier: 0.1044 (0.1398)  loss_box_reg: 0.1091 (0.1237)  loss_mask: 0.2795 (0.3386)  loss_objectness: 0.0067 (0.0187)  loss_rpn_box_reg: 0.0032 (0.0046)  time: 0.4291  data: 0.0179  max mem: 6079
# Epoch: [0]  [3100/7828]  eta: 0:33:45  lr: 0.001000  loss: 0.5090 (0.6224)  loss_classifier: 0.1044 (0.1390)  loss_box_reg: 0.1133 (0.1236)  loss_mask: 0.2799 (0.3368)  loss_objectness: 0.0069 (0.0184)  loss_rpn_box_reg: 0.0032 (0.0046)  time: 0.4303  data: 0.0201  max mem: 6079
# Epoch: [0]  [3200/7828]  eta: 0:33:02  lr: 0.001000  loss: 0.5080 (0.6195)  loss_classifier: 0.0981 (0.1380)  loss_box_reg: 0.1197 (0.1234)  loss_mask: 0.2674 (0.3352)  loss_objectness: 0.0082 (0.0182)  loss_rpn_box_reg: 0.0031 (0.0046)  time: 0.4325  data: 0.0193  max mem: 6079
# Epoch: [0]  [3300/7828]  eta: 0:32:19  lr: 0.001000  loss: 0.5301 (0.6167)  loss_classifier: 0.1083 (0.1372)  loss_box_reg: 0.1125 (0.1233)  loss_mask: 0.2964 (0.3337)  loss_objectness: 0.0116 (0.0180)  loss_rpn_box_reg: 0.0035 (0.0046)  time: 0.4296  data: 0.0188  max mem: 6079
# Epoch: [0]  [3400/7828]  eta: 0:31:37  lr: 0.001000  loss: 0.5240 (0.6138)  loss_classifier: 0.0994 (0.1362)  loss_box_reg: 0.1201 (0.1231)  loss_mask: 0.2935 (0.3321)  loss_objectness: 0.0068 (0.0178)  loss_rpn_box_reg: 0.0037 (0.0045)  time: 0.4325  data: 0.0207  max mem: 6079
# Epoch: [0]  [3500/7828]  eta: 0:30:54  lr: 0.001000  loss: 0.5229 (0.6112)  loss_classifier: 0.1065 (0.1355)  loss_box_reg: 0.1186 (0.1229)  loss_mask: 0.2774 (0.3307)  loss_objectness: 0.0085 (0.0176)  loss_rpn_box_reg: 0.0035 (0.0045)  time: 0.4315  data: 0.0206  max mem: 6079
# Epoch: [0]  [3600/7828]  eta: 0:30:12  lr: 0.001000  loss: 0.5212 (0.6086)  loss_classifier: 0.1120 (0.1347)  loss_box_reg: 0.1137 (0.1226)  loss_mask: 0.2812 (0.3293)  loss_objectness: 0.0088 (0.0174)  loss_rpn_box_reg: 0.0038 (0.0045)  time: 0.4301  data: 0.0195  max mem: 6079
# Epoch: [0]  [3700/7828]  eta: 0:29:29  lr: 0.001000  loss: 0.4663 (0.6057)  loss_classifier: 0.0909 (0.1337)  loss_box_reg: 0.1081 (0.1223)  loss_mask: 0.2680 (0.3279)  loss_objectness: 0.0072 (0.0172)  loss_rpn_box_reg: 0.0033 (0.0045)  time: 0.4305  data: 0.0202  max mem: 6079
# Epoch: [0]  [3800/7828]  eta: 0:28:46  lr: 0.001000  loss: 0.5389 (0.6035)  loss_classifier: 0.1109 (0.1330)  loss_box_reg: 0.1147 (0.1223)  loss_mask: 0.2916 (0.3267)  loss_objectness: 0.0077 (0.0170)  loss_rpn_box_reg: 0.0030 (0.0045)  time: 0.4315  data: 0.0203  max mem: 6079
# Epoch: [0]  [3900/7828]  eta: 0:28:04  lr: 0.001000  loss: 0.4851 (0.6012)  loss_classifier: 0.0912 (0.1322)  loss_box_reg: 0.1057 (0.1222)  loss_mask: 0.2743 (0.3254)  loss_objectness: 0.0070 (0.0169)  loss_rpn_box_reg: 0.0029 (0.0044)  time: 0.4290  data: 0.0180  max mem: 6079
# Epoch: [0]  [4000/7828]  eta: 0:27:21  lr: 0.001000  loss: 0.4986 (0.5989)  loss_classifier: 0.1004 (0.1315)  loss_box_reg: 0.1162 (0.1220)  loss_mask: 0.2663 (0.3243)  loss_objectness: 0.0075 (0.0167)  loss_rpn_box_reg: 0.0039 (0.0044)  time: 0.4304  data: 0.0181  max mem: 6079
# Epoch: [0]  [4100/7828]  eta: 0:26:38  lr: 0.001000  loss: 0.5314 (0.5970)  loss_classifier: 0.1043 (0.1309)  loss_box_reg: 0.1204 (0.1220)  loss_mask: 0.2807 (0.3232)  loss_objectness: 0.0091 (0.0165)  loss_rpn_box_reg: 0.0047 (0.0044)  time: 0.4310  data: 0.0188  max mem: 6079
# Epoch: [0]  [4200/7828]  eta: 0:25:55  lr: 0.001000  loss: 0.5342 (0.5951)  loss_classifier: 0.1104 (0.1302)  loss_box_reg: 0.1284 (0.1219)  loss_mask: 0.2861 (0.3221)  loss_objectness: 0.0094 (0.0164)  loss_rpn_box_reg: 0.0042 (0.0044)  time: 0.4306  data: 0.0180  max mem: 6079
# Epoch: [0]  [4300/7828]  eta: 0:25:13  lr: 0.001000  loss: 0.5117 (0.5933)  loss_classifier: 0.0999 (0.1297)  loss_box_reg: 0.1079 (0.1218)  loss_mask: 0.2721 (0.3212)  loss_objectness: 0.0098 (0.0162)  loss_rpn_box_reg: 0.0032 (0.0044)  time: 0.4276  data: 0.0180  max mem: 6079
# Epoch: [0]  [4400/7828]  eta: 0:24:30  lr: 0.001000  loss: 0.5131 (0.5912)  loss_classifier: 0.1036 (0.1290)  loss_box_reg: 0.1208 (0.1217)  loss_mask: 0.2791 (0.3201)  loss_objectness: 0.0079 (0.0161)  loss_rpn_box_reg: 0.0042 (0.0044)  time: 0.4302  data: 0.0186  max mem: 6079
# Epoch: [0]  [4500/7828]  eta: 0:23:47  lr: 0.001000  loss: 0.4995 (0.5894)  loss_classifier: 0.0974 (0.1284)  loss_box_reg: 0.1213 (0.1216)  loss_mask: 0.2750 (0.3191)  loss_objectness: 0.0097 (0.0160)  loss_rpn_box_reg: 0.0033 (0.0044)  time: 0.4316  data: 0.0198  max mem: 6079
# Epoch: [0]  [4600/7828]  eta: 0:23:04  lr: 0.001000  loss: 0.5152 (0.5879)  loss_classifier: 0.0948 (0.1279)  loss_box_reg: 0.1225 (0.1215)  loss_mask: 0.2734 (0.3183)  loss_objectness: 0.0088 (0.0159)  loss_rpn_box_reg: 0.0030 (0.0044)  time: 0.4328  data: 0.0197  max mem: 6079
# Epoch: [0]  [4700/7828]  eta: 0:22:22  lr: 0.001000  loss: 0.5028 (0.5863)  loss_classifier: 0.1019 (0.1274)  loss_box_reg: 0.1193 (0.1214)  loss_mask: 0.2709 (0.3174)  loss_objectness: 0.0090 (0.0157)  loss_rpn_box_reg: 0.0031 (0.0043)  time: 0.4325  data: 0.0197  max mem: 6079
# Epoch: [0]  [4800/7828]  eta: 0:21:39  lr: 0.001000  loss: 0.5033 (0.5847)  loss_classifier: 0.0929 (0.1269)  loss_box_reg: 0.1165 (0.1214)  loss_mask: 0.2691 (0.3165)  loss_objectness: 0.0077 (0.0156)  loss_rpn_box_reg: 0.0037 (0.0043)  time: 0.4319  data: 0.0195  max mem: 6079
# Epoch: [0]  [4900/7828]  eta: 0:20:56  lr: 0.001000  loss: 0.4813 (0.5830)  loss_classifier: 0.0903 (0.1263)  loss_box_reg: 0.1176 (0.1212)  loss_mask: 0.2759 (0.3156)  loss_objectness: 0.0072 (0.0155)  loss_rpn_box_reg: 0.0035 (0.0043)  time: 0.4276  data: 0.0171  max mem: 6079
# Epoch: [0]  [5000/7828]  eta: 0:20:13  lr: 0.001000  loss: 0.5066 (0.5814)  loss_classifier: 0.0933 (0.1259)  loss_box_reg: 0.1113 (0.1211)  loss_mask: 0.2760 (0.3148)  loss_objectness: 0.0085 (0.0154)  loss_rpn_box_reg: 0.0033 (0.0043)  time: 0.4284  data: 0.0179  max mem: 6079
# Epoch: [0]  [5100/7828]  eta: 0:19:30  lr: 0.001000  loss: 0.4623 (0.5796)  loss_classifier: 0.0857 (0.1252)  loss_box_reg: 0.1031 (0.1209)  loss_mask: 0.2531 (0.3139)  loss_objectness: 0.0069 (0.0152)  loss_rpn_box_reg: 0.0034 (0.0043)  time: 0.4293  data: 0.0186  max mem: 6079
# Epoch: [0]  [5200/7828]  eta: 0:18:47  lr: 0.001000  loss: 0.5003 (0.5781)  loss_classifier: 0.0978 (0.1248)  loss_box_reg: 0.1105 (0.1208)  loss_mask: 0.2782 (0.3131)  loss_objectness: 0.0070 (0.0151)  loss_rpn_box_reg: 0.0032 (0.0043)  time: 0.4321  data: 0.0198  max mem: 6079
# Epoch: [0]  [5300/7828]  eta: 0:18:04  lr: 0.001000  loss: 0.4532 (0.5767)  loss_classifier: 0.0878 (0.1244)  loss_box_reg: 0.1023 (0.1207)  loss_mask: 0.2582 (0.3123)  loss_objectness: 0.0068 (0.0150)  loss_rpn_box_reg: 0.0039 (0.0043)  time: 0.4279  data: 0.0172  max mem: 6079
# Epoch: [0]  [5400/7828]  eta: 0:17:22  lr: 0.001000  loss: 0.4918 (0.5752)  loss_classifier: 0.0987 (0.1239)  loss_box_reg: 0.1121 (0.1206)  loss_mask: 0.2711 (0.3116)  loss_objectness: 0.0067 (0.0149)  loss_rpn_box_reg: 0.0029 (0.0043)  time: 0.4297  data: 0.0188  max mem: 6079
# Epoch: [0]  [5500/7828]  eta: 0:16:39  lr: 0.001000  loss: 0.4676 (0.5736)  loss_classifier: 0.0944 (0.1234)  loss_box_reg: 0.1032 (0.1204)  loss_mask: 0.2534 (0.3107)  loss_objectness: 0.0092 (0.0148)  loss_rpn_box_reg: 0.0028 (0.0042)  time: 0.4292  data: 0.0178  max mem: 6079
# Epoch: [0]  [5600/7828]  eta: 0:15:56  lr: 0.001000  loss: 0.4944 (0.5721)  loss_classifier: 0.1004 (0.1230)  loss_box_reg: 0.1141 (0.1203)  loss_mask: 0.2657 (0.3099)  loss_objectness: 0.0078 (0.0147)  loss_rpn_box_reg: 0.0032 (0.0042)  time: 0.4304  data: 0.0182  max mem: 6079
# Epoch: [0]  [5700/7828]  eta: 0:15:13  lr: 0.001000  loss: 0.4896 (0.5706)  loss_classifier: 0.0926 (0.1225)  loss_box_reg: 0.1080 (0.1202)  loss_mask: 0.2670 (0.3091)  loss_objectness: 0.0072 (0.0146)  loss_rpn_box_reg: 0.0030 (0.0042)  time: 0.4314  data: 0.0199  max mem: 6079
# Epoch: [0]  [5800/7828]  eta: 0:14:30  lr: 0.001000  loss: 0.4660 (0.5692)  loss_classifier: 0.0914 (0.1221)  loss_box_reg: 0.1102 (0.1201)  loss_mask: 0.2664 (0.3084)  loss_objectness: 0.0071 (0.0145)  loss_rpn_box_reg: 0.0028 (0.0042)  time: 0.4286  data: 0.0172  max mem: 6079
# Epoch: [0]  [5900/7828]  eta: 0:13:47  lr: 0.001000  loss: 0.4733 (0.5680)  loss_classifier: 0.0857 (0.1217)  loss_box_reg: 0.1101 (0.1200)  loss_mask: 0.2629 (0.3077)  loss_objectness: 0.0061 (0.0144)  loss_rpn_box_reg: 0.0035 (0.0042)  time: 0.4311  data: 0.0194  max mem: 6079
# Epoch: [0]  [6000/7828]  eta: 0:13:04  lr: 0.001000  loss: 0.4935 (0.5668)  loss_classifier: 0.0962 (0.1213)  loss_box_reg: 0.1097 (0.1199)  loss_mask: 0.2702 (0.3071)  loss_objectness: 0.0071 (0.0143)  loss_rpn_box_reg: 0.0026 (0.0042)  time: 0.4279  data: 0.0172  max mem: 6079
# Epoch: [0]  [6100/7828]  eta: 0:12:21  lr: 0.001000  loss: 0.5111 (0.5657)  loss_classifier: 0.0993 (0.1210)  loss_box_reg: 0.1171 (0.1199)  loss_mask: 0.2670 (0.3064)  loss_objectness: 0.0079 (0.0142)  loss_rpn_box_reg: 0.0032 (0.0042)  time: 0.4303  data: 0.0185  max mem: 6079
# Epoch: [0]  [6200/7828]  eta: 0:11:39  lr: 0.001000  loss: 0.4935 (0.5646)  loss_classifier: 0.0951 (0.1207)  loss_box_reg: 0.1176 (0.1198)  loss_mask: 0.2606 (0.3058)  loss_objectness: 0.0065 (0.0141)  loss_rpn_box_reg: 0.0037 (0.0042)  time: 0.4359  data: 0.0222  max mem: 6079
# Epoch: [0]  [6300/7828]  eta: 0:10:56  lr: 0.001000  loss: 0.4682 (0.5634)  loss_classifier: 0.0909 (0.1203)  loss_box_reg: 0.1090 (0.1197)  loss_mask: 0.2577 (0.3053)  loss_objectness: 0.0052 (0.0140)  loss_rpn_box_reg: 0.0028 (0.0041)  time: 0.4323  data: 0.0195  max mem: 6079
# Epoch: [0]  [6400/7828]  eta: 0:10:13  lr: 0.001000  loss: 0.4814 (0.5622)  loss_classifier: 0.0868 (0.1199)  loss_box_reg: 0.1074 (0.1196)  loss_mask: 0.2626 (0.3046)  loss_objectness: 0.0061 (0.0139)  loss_rpn_box_reg: 0.0038 (0.0041)  time: 0.4309  data: 0.0188  max mem: 6079
# Epoch: [0]  [6500/7828]  eta: 0:09:30  lr: 0.001000  loss: 0.4983 (0.5612)  loss_classifier: 0.1039 (0.1196)  loss_box_reg: 0.1116 (0.1195)  loss_mask: 0.2582 (0.3041)  loss_objectness: 0.0076 (0.0139)  loss_rpn_box_reg: 0.0035 (0.0041)  time: 0.4324  data: 0.0202  max mem: 6079
# Epoch: [0]  [6600/7828]  eta: 0:08:47  lr: 0.001000  loss: 0.4891 (0.5601)  loss_classifier: 0.0915 (0.1192)  loss_box_reg: 0.1089 (0.1194)  loss_mask: 0.2731 (0.3036)  loss_objectness: 0.0079 (0.0138)  loss_rpn_box_reg: 0.0027 (0.0041)  time: 0.4330  data: 0.0206  max mem: 6079
# Epoch: [0]  [6700/7828]  eta: 0:08:04  lr: 0.001000  loss: 0.4988 (0.5591)  loss_classifier: 0.0949 (0.1189)  loss_box_reg: 0.1055 (0.1193)  loss_mask: 0.2700 (0.3031)  loss_objectness: 0.0072 (0.0137)  loss_rpn_box_reg: 0.0030 (0.0041)  time: 0.4289  data: 0.0181  max mem: 6079
# Epoch: [0]  [6800/7828]  eta: 0:07:21  lr: 0.001000  loss: 0.4824 (0.5580)  loss_classifier: 0.0988 (0.1186)  loss_box_reg: 0.1108 (0.1192)  loss_mask: 0.2583 (0.3025)  loss_objectness: 0.0074 (0.0136)  loss_rpn_box_reg: 0.0034 (0.0041)  time: 0.4287  data: 0.0184  max mem: 6079
# Epoch: [0]  [6900/7828]  eta: 0:06:38  lr: 0.001000  loss: 0.4764 (0.5571)  loss_classifier: 0.0906 (0.1183)  loss_box_reg: 0.1115 (0.1192)  loss_mask: 0.2752 (0.3020)  loss_objectness: 0.0072 (0.0136)  loss_rpn_box_reg: 0.0035 (0.0041)  time: 0.4263  data: 0.0163  max mem: 6079
# Epoch: [0]  [7000/7828]  eta: 0:05:55  lr: 0.001000  loss: 0.4737 (0.5563)  loss_classifier: 0.0883 (0.1181)  loss_box_reg: 0.1136 (0.1191)  loss_mask: 0.2653 (0.3015)  loss_objectness: 0.0074 (0.0135)  loss_rpn_box_reg: 0.0035 (0.0041)  time: 0.4299  data: 0.0181  max mem: 6079
# Epoch: [0]  [7100/7828]  eta: 0:05:12  lr: 0.001000  loss: 0.4941 (0.5555)  loss_classifier: 0.0972 (0.1178)  loss_box_reg: 0.1191 (0.1190)  loss_mask: 0.2696 (0.3011)  loss_objectness: 0.0072 (0.0134)  loss_rpn_box_reg: 0.0028 (0.0041)  time: 0.4392  data: 0.0230  max mem: 6079
# Epoch: [0]  [7200/7828]  eta: 0:04:29  lr: 0.001000  loss: 0.4665 (0.5546)  loss_classifier: 0.0841 (0.1175)  loss_box_reg: 0.1182 (0.1190)  loss_mask: 0.2516 (0.3006)  loss_objectness: 0.0056 (0.0134)  loss_rpn_box_reg: 0.0029 (0.0041)  time: 0.4317  data: 0.0181  max mem: 6079
# Epoch: [0]  [7300/7828]  eta: 0:03:46  lr: 0.001000  loss: 0.4807 (0.5536)  loss_classifier: 0.0979 (0.1172)  loss_box_reg: 0.1166 (0.1189)  loss_mask: 0.2663 (0.3001)  loss_objectness: 0.0063 (0.0133)  loss_rpn_box_reg: 0.0035 (0.0041)  time: 0.4313  data: 0.0189  max mem: 6079
# Epoch: [0]  [7400/7828]  eta: 0:03:03  lr: 0.001000  loss: 0.4766 (0.5527)  loss_classifier: 0.0890 (0.1169)  loss_box_reg: 0.1150 (0.1189)  loss_mask: 0.2635 (0.2995)  loss_objectness: 0.0094 (0.0132)  loss_rpn_box_reg: 0.0043 (0.0041)  time: 0.4310  data: 0.0187  max mem: 6079
# Epoch: [0]  [7500/7828]  eta: 0:02:20  lr: 0.001000  loss: 0.4811 (0.5519)  loss_classifier: 0.0962 (0.1167)  loss_box_reg: 0.1148 (0.1189)  loss_mask: 0.2487 (0.2991)  loss_objectness: 0.0077 (0.0132)  loss_rpn_box_reg: 0.0032 (0.0041)  time: 0.4331  data: 0.0194  max mem: 6079
# Epoch: [0]  [7600/7828]  eta: 0:01:37  lr: 0.001000  loss: 0.4833 (0.5511)  loss_classifier: 0.0958 (0.1165)  loss_box_reg: 0.1108 (0.1188)  loss_mask: 0.2681 (0.2987)  loss_objectness: 0.0069 (0.0131)  loss_rpn_box_reg: 0.0033 (0.0041)  time: 0.4310  data: 0.0194  max mem: 6079
# Epoch: [0]  [7700/7828]  eta: 0:00:55  lr: 0.001000  loss: 0.4848 (0.5502)  loss_classifier: 0.0917 (0.1162)  loss_box_reg: 0.1113 (0.1187)  loss_mask: 0.2604 (0.2982)  loss_objectness: 0.0049 (0.0131)  loss_rpn_box_reg: 0.0033 (0.0040)  time: 0.4316  data: 0.0183  max mem: 6079
# Epoch: [0]  [7800/7828]  eta: 0:00:12  lr: 0.001000  loss: 0.4903 (0.5495)  loss_classifier: 0.0988 (0.1160)  loss_box_reg: 0.1077 (0.1187)  loss_mask: 0.2645 (0.2978)  loss_objectness: 0.0091 (0.0130)  loss_rpn_box_reg: 0.0027 (0.0040)  time: 0.4305  data: 0.0195  max mem: 6079
# Epoch: [0]  [7827/7828]  eta: 0:00:00  lr: 0.001000  loss: 0.4609 (0.5492)  loss_classifier: 0.0867 (0.1159)  loss_box_reg: 0.1014 (0.1186)  loss_mask: 0.2665 (0.2976)  loss_objectness: 0.0059 (0.0130)  loss_rpn_box_reg: 0.0029 (0.0040)  time: 0.4225  data: 0.0185  max mem: 6079
# Epoch: [0] Total time: 0:56:04 (0.4298 s / it)

# %% [markdown]
# # 추론 및 제출
#
# 각 테스트 파일에서 검출된 결과를 기록합니다.
#
# 하나의 테스트 파일에서 복수의 객체가 검출되었을 경우 복수의 결과를 기록합니다.
#
# 본 baseline에서는 score 0.8 이상의 결과만 기록하여 제출하였습니다.
#
# [point1_x, point1_y] ~ [point4_x, point4_y]에 시계방향으로 객체의 4개 꼭지점 좌표를 기록합니다.
#
# class_id는 제공된 class_id_info.csv의 class_id값을 기록합니다.
#
# 제출파일은 최대 30000줄까지 기록 가능합니다.

# %%
threshold = 0
results = {
    'file_name':[], 'class_id':[], 'confidence':[], 'point1_x':[], 'point1_y':[],
    'point2_x':[], 'point2_y':[], 'point3_x':[], 'point3_y':[], 'point4_x':[], 'point4_y':[]
}
model.eval()
for img, target in tqdm(test_dataset):
    with torch.no_grad():
        prediction = model([img.to(device)])[0]
    
    idx = np.where(prediction['scores'].cpu().numpy() > threshold)[0]
    for i in idx:
        x_min, y_min, x_max, y_max = prediction['boxes'].cpu().numpy()[i]
        class_id = prediction['labels'].cpu().numpy()[i]
        confidence = prediction['scores'].cpu().numpy()[i]
        
        results['file_name'].append(target['file_name'])
        results['class_id'].append(class_id)
        results['confidence'].append(confidence)
        results['point1_x'].append(x_min)
        results['point1_y'].append(y_min)
        results['point2_x'].append(x_max)
        results['point2_y'].append(y_min)
        results['point3_x'].append(x_max)
        results['point3_y'].append(y_max)
        results['point4_x'].append(x_min)
        results['point4_y'].append(y_max)
# Out:
#   0%|          | 20/20874 [00:22<6:23:48,  1.10s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-1d3e1456f080> in <module>
#       7 for img, target in tqdm(test_dataset):
#       8     with torch.no_grad():
# ----> 9         prediction = model([img.to(device)])[0]
#      10
#      11     idx = np.where(prediction['scores'].cpu().numpy() > threshold)[0]
#
# ~/anaconda3/envs/comet/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/anaconda3/envs/comet/lib/python3.7/site-packages/torchvision/models/detection/generalized_rcnn.py in forward(self, images, targets)
#      95             features = OrderedDict([('0', features)])
#      96         proposals, proposal_losses = self.rpn(images, features, targets)
# ---> 97         detections, detector_losses = self.roi_heads(features, proposals, images.image_sizes, targets)
#      98         detections = self.transform.postprocess(detections, images.image_sizes, original_image_sizes)
#      99
#
# ~/anaconda3/envs/comet/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/anaconda3/envs/comet/lib/python3.7/site-packages/torchvision/models/detection/roi_heads.py in forward(self, features, proposals, image_shapes, targets)
#     750             matched_idxs = None
#     751
# --> 752         box_features = self.box_roi_pool(features, proposals, image_shapes)
#     753         box_features = self.box_head(box_features)
#     754         class_logits, box_regression = self.box_predictor(box_features)
#
# ~/anaconda3/envs/comet/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/anaconda3/envs/comet/lib/python3.7/site-packages/torchvision/ops/poolers.py in forward(self, x, boxes, image_shapes)
#     254                 per_level_feature, rois_per_level,
#     255                 output_size=self.output_size,
# --> 256                 spatial_scale=scale, sampling_ratio=self.sampling_ratio)
#     257
#     258             if torchvision._is_tracing():
#
# ~/anaconda3/envs/comet/lib/python3.7/site-packages/torchvision/ops/roi_align.py in roi_align(input, boxes, output_size, spatial_scale, sampling_ratio, aligned)
#      56     return torch.ops.torchvision.roi_align(input, rois, spatial_scale,
#      57                                            output_size[0], output_size[1],
# ---> 58                                            sampling_ratio, aligned)
#      59
#      60
#
# KeyboardInterrupt:

# %%
submission = pd.DataFrame(results)
submission.shape
# Out:
# (2000, 11)

# %%
submission = pd.DataFrame(results)
submission.shape
# Out:
# (19747, 11)

# %%
submission.head()
# Out:
#           file_name  class_id  confidence    point1_x    point1_y    point2_x  \
# 0  test_200000.json         1    0.848953  173.362625  243.217102  246.198914
# 1  test_200001.json         1    0.969953  117.212143  331.850525  257.011536
# 2  test_200001.json         1    0.956206  410.833282  197.945801  514.528564
# 3  test_200002.json         2    0.865272  222.203674  345.843170  313.287109
# 4  test_200003.json         2    0.950695  131.962753    6.786884  291.662659
#
#      point2_y    point3_x    point3_y    point4_x    point4_y
# 0  243.217102  246.198914  323.386047  173.362625  323.386047
# 1  331.850525  257.011536  476.951202  117.212143  476.951202
# 2  197.945801  514.528564  308.734009  410.833282  308.734009
# 3  345.843170  313.287109  458.262360  222.203674  458.262360
# 4    6.786884  291.662659  198.216171  131.962753  198.216171

# %%
submission.to_csv('baseline.csv', index=False)
