# %%
import glob

# %%
glob.glob('*/*')
# Out:
# ['fast_rcnn/README.md',
#  'fast_rcnn/fast_rcnn_r101_fpn_2x_coco.py',
#  'fast_rcnn/fast_rcnn_r50_fpn_2x_coco.py',
#  'fast_rcnn/fast_rcnn_r50_caffe_fpn_1x_coco.py',
#  'fast_rcnn/fast_rcnn_r101_caffe_fpn_1x_coco.py',
#  'fast_rcnn/fast_rcnn_r50_fpn_1x_coco.py',
#  'fast_rcnn/fast_rcnn_r101_fpn_1x_coco.py',
#  'yolof/README.md',
#  'yolof/yolof_r50_c5_8x8_iter-1x_coco.py',
#  'yolof/metafile.yml',
#  'yolof/yolof_r50_c5_8x8_1x_coco.py',
#  'mask2former/README.md',
#  'mask2former/metafile.yml',
#  'mask2former/mask2former_r50_lsj_8x2_50e_coco.py',
#  'mask2former/mask2former_r101_lsj_8x2_50e_coco-panoptic.py',
#  'mask2former/mask2former_swin-t-p4-w7-224_lsj_8x2_50e_coco-panoptic.py',
#  'mask2former/mask2former_r101_lsj_8x2_50e_coco.py',
#  'mask2former/mask2former_r50_lsj_8x2_50e_coco-panoptic.py',
#  'mask2former/mask2former_swin-b-p4-w12-384_lsj_8x2_50e_coco-panoptic.py',
#  'mask2former/mask2former_swin-t-p4-w7-224_lsj_8x2_50e_coco.py',
# ...
