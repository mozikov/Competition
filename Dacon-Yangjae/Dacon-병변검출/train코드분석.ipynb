# %%
import argparse
import copy
import os
import os.path as osp
import time
import warnings

import mmcv
import torch
from mmcv import Config, DictAction
from mmcv.runner import get_dist_info, init_dist
from mmcv.utils import get_git_hash

from mmdet import __version__
from mmdet.apis import init_random_seed, set_random_seed, train_detector
from mmdet.datasets import build_dataset
from mmdet.models import build_detector
from mmdet.utils import collect_env, get_root_logger

import json
from cv2 import cv2
import matplotlib.pyplot as plt



parser = argparse.ArgumentParser(description='Train a detector')
parser.add_argument('--work-dir', help='the dir to save logs and models')
parser.add_argument(
    '--resume-from', help='the checkpoint file to resume from')
parser.add_argument(
    '--no-validate',
    action='store_true',
    help='whether not to evaluate the checkpoint during training')
group_gpus = parser.add_mutually_exclusive_group()
group_gpus.add_argument(
    '--gpus',
    type=int,
    help='number of gpus to use '
    '(only applicable to non-distributed training)')
group_gpus.add_argument(
    '--gpu-ids',
    type=int,
    nargs='+',
    help='ids of gpus to use '
    '(only applicable to non-distributed training)')
parser.add_argument('--seed', type=int, default=None, help='random seed')
parser.add_argument(
    '--deterministic',
    action='store_true',
    help='whether to set deterministic options for CUDNN backend.')
parser.add_argument(
    '--options',
    nargs='+',
    action=DictAction,
    help='override some settings in the used config, the key-value pair '
    'in xxx=yyy format will be merged into config file (deprecate), '
    'change to --cfg-options instead.')
parser.add_argument(
    '--cfg-options',
    nargs='+',
    action=DictAction,
    help='override some settings in the used config, the key-value pair '
    'in xxx=yyy format will be merged into config file. If the value to '
    'be overwritten is a list, it should be like key="[a,b]" or key=a,b '
    'It also allows nested list/tuple values, e.g. key="[(a,b),(c,d)]" '
    'Note that the quotation marks are necessary and that no white space '
    'is allowed.')
parser.add_argument(
    '--launcher',
    choices=['none', 'pytorch', 'slurm', 'mpi'],
    default='none',
    help='job launcher')
parser.add_argument('--local_rank', type=int, default=0)
args = parser.parse_args(args=[])

# %%
config = 'configs/balloon/mask_rcnn_r50_caffe_fpn_mstrain-poly_1x_balloon.py'

# %%
config = 'configs/balloon/mask_rcnn_r50_caffe_fpn_mstrain-poly_1x_balloon_dacon.py'

# %%
config = 'configs/balloon/faster_rcnn_r50_caffe_fpn_mstrain-poly_1x_balloon_dacon.py'

# %%
cfg = Config.fromfile(config)

# %%
cfg.data.test
# Out:
# {'type': 'CocoDataset',
#  'ann_file': 'data/dacon/test_annotations.json',
#  'img_prefix': 'data/dacon/test_image/',
#  'pipeline': [{'type': 'LoadImageFromFile'},
#   {'type': 'MultiScaleFlipAug',
#    'img_scale': (1333, 800),
#    'flip': True,
#    'transforms': [{'type': 'Resize', 'keep_ratio': True},
#     {'type': 'RandomFlip'},
#     {'type': 'Normalize',
#      'mean': [123.675, 116.28, 103.53],
#      'std': [58.395, 57.12, 57.375],
#      'to_rgb': True},
#     {'type': 'Pad', 'size_divisor': 32},
#     {'type': 'ImageToTensor', 'keys': ['img']},
#     {'type': 'Collect', 'keys': ['img']}]}],
#  'classes': ('01_ulcer', '02_mass', '04_lymph', '05_bleeding')}

# %%
from glob import glob

# %%
sorted(glob('data/dacon/test_image/*'))
# Out:
# ['data/dacon/test_image/test_200000.jpg',
#  'data/dacon/test_image/test_200001.jpg',
#  'data/dacon/test_image/test_200002.jpg',
#  'data/dacon/test_image/test_200003.jpg',
#  'data/dacon/test_image/test_200004.jpg',
#  'data/dacon/test_image/test_200005.jpg',
#  'data/dacon/test_image/test_200006.jpg',
#  'data/dacon/test_image/test_200007.jpg',
#  'data/dacon/test_image/test_200008.jpg',
#  'data/dacon/test_image/test_200009.jpg',
#  'data/dacon/test_image/test_200010.jpg',
#  'data/dacon/test_image/test_200011.jpg',
#  'data/dacon/test_image/test_200012.jpg',
#  'data/dacon/test_image/test_200013.jpg',
#  'data/dacon/test_image/test_200014.jpg',
#  'data/dacon/test_image/test_200015.jpg',
#  'data/dacon/test_image/test_200016.jpg',
#  'data/dacon/test_image/test_200017.jpg',
#  'data/dacon/test_image/test_200018.jpg',
#  'data/dacon/test_image/test_200019.jpg',
#  'data/dacon/test_image/test_200020.jpg',
#  'data/dacon/test_image/test_200021.jpg',
#  'data/dacon/test_image/test_200022.jpg',
#  'data/dacon/test_image/test_200023.jpg',
#  'data/dacon/test_image/test_200024.jpg',
#  'data/dacon/test_image/test_200025.jpg',
#  'data/dacon/test_image/test_200026.jpg',
#  'data/dacon/test_image/test_200027.jpg',
#  'data/dacon/test_image/test_200028.jpg',
#  'data/dacon/test_image/test_200029.jpg',
#  'data/dacon/test_image/test_200030.jpg',
#  'data/dacon/test_image/test_200031.jpg',
#  'data/dacon/test_image/test_200032.jpg',
#  'data/dacon/test_image/test_200033.jpg',
#  'data/dacon/test_image/test_200034.jpg',
#  'data/dacon/test_image/test_200035.jpg',
#  'data/dacon/test_image/test_200036.jpg',
#  'data/dacon/test_image/test_200037.jpg',
#  'data/dacon/test_image/test_200038.jpg',
#  'data/dacon/test_image/test_200039.jpg',
#  'data/dacon/test_image/test_200040.jpg',
#  'data/dacon/test_image/test_200041.jpg',
#  'data/dacon/test_image/test_200042.jpg',
#  'data/dacon/test_image/test_200043.jpg',
#  'data/dacon/test_image/test_200044.jpg',
#  'data/dacon/test_image/test_200045.jpg',
#  'data/dacon/test_image/test_200046.jpg',
#  'data/dacon/test_image/test_200047.jpg',
#  'data/dacon/test_image/test_200048.jpg',
#  'data/dacon/test_image/test_200049.jpg',
#  'data/dacon/test_image/test_200050.jpg',
#  'data/dacon/test_image/test_200051.jpg',
#  'data/dacon/test_image/test_200052.jpg',
#  'data/dacon/test_image/test_200053.jpg',
#  'data/dacon/test_image/test_200054.jpg',
#  'data/dacon/test_image/test_200055.jpg',
#  'data/dacon/test_image/test_200056.jpg',
#  'data/dacon/test_image/test_200057.jpg',
#  'data/dacon/test_image/test_200058.jpg',
#  'data/dacon/test_image/test_200059.jpg',
#  'data/dacon/test_image/test_200060.jpg',
#  'data/dacon/test_image/test_200061.jpg',
#  'data/dacon/test_image/test_200062.jpg',
#  'data/dacon/test_image/test_200063.jpg',
#  'data/dacon/test_image/test_200064.jpg',
#  'data/dacon/test_image/test_200065.jpg',
#  'data/dacon/test_image/test_200066.jpg',
#  'data/dacon/test_image/test_200067.jpg',
#  'data/dacon/test_image/test_200068.jpg',
#  'data/dacon/test_image/test_200069.jpg',
#  'data/dacon/test_image/test_200070.jpg',
#  'data/dacon/test_image/test_200071.jpg',
#  'data/dacon/test_image/test_200072.jpg',
#  'data/dacon/test_image/test_200073.jpg',
#  'data/dacon/test_image/test_200074.jpg',
#  'data/dacon/test_image/test_200075.jpg',
#  'data/dacon/test_image/test_200076.jpg',
#  'data/dacon/test_image/test_200077.jpg',
#  'data/dacon/test_image/test_200078.jpg',
#  'data/dacon/test_image/test_200079.jpg',
#  'data/dacon/test_image/test_200080.jpg',
#  'data/dacon/test_image/test_200081.jpg',
#  'data/dacon/test_image/test_200082.jpg',
#  'data/dacon/test_image/test_200083.jpg',
#  'data/dacon/test_image/test_200084.jpg',
#  'data/dacon/test_image/test_200085.jpg',
#  'data/dacon/test_image/test_200086.jpg',
#  'data/dacon/test_image/test_200087.jpg',
#  'data/dacon/test_image/test_200088.jpg',
#  'data/dacon/test_image/test_200089.jpg',
#  'data/dacon/test_image/test_200090.jpg',
#  'data/dacon/test_image/test_200091.jpg',
#  'data/dacon/test_image/test_200092.jpg',
#  'data/dacon/test_image/test_200093.jpg',
#  'data/dacon/test_image/test_200094.jpg',
#  'data/dacon/test_image/test_200095.jpg',
#  'data/dacon/test_image/test_200096.jpg',
#  'data/dacon/test_image/test_200097.jpg',
#  'data/dacon/test_image/test_200098.jpg',
#  'data/dacon/test_image/test_200099.jpg',
#  'data/dacon/test_image/test_200100.jpg',
#  'data/dacon/test_image/test_200101.jpg',
#  'data/dacon/test_image/test_200102.jpg',
#  'data/dacon/test_image/test_200103.jpg',
#  'data/dacon/test_image/test_200104.jpg',
#  'data/dacon/test_image/test_200105.jpg',
#  'data/dacon/test_image/test_200106.jpg',
#  'data/dacon/test_image/test_200107.jpg',
#  'data/dacon/test_image/test_200108.jpg',
#  'data/dacon/test_image/test_200109.jpg',
#  'data/dacon/test_image/test_200110.jpg',
#  'data/dacon/test_image/test_200111.jpg',
#  'data/dacon/test_image/test_200112.jpg',
#  'data/dacon/test_image/test_200113.jpg',
#  'data/dacon/test_image/test_200114.jpg',
#  'data/dacon/test_image/test_200115.jpg',
#  'data/dacon/test_image/test_200116.jpg',
#  'data/dacon/test_image/test_200117.jpg',
#  'data/dacon/test_image/test_200118.jpg',
#  'data/dacon/test_image/test_200119.jpg',
#  'data/dacon/test_image/test_200120.jpg',
#  'data/dacon/test_image/test_200121.jpg',
#  'data/dacon/test_image/test_200122.jpg',
#  'data/dacon/test_image/test_200123.jpg',
#  'data/dacon/test_image/test_200124.jpg',
#  'data/dacon/test_image/test_200125.jpg',
#  'data/dacon/test_image/test_200126.jpg',
#  'data/dacon/test_image/test_200127.jpg',
#  'data/dacon/test_image/test_200128.jpg',
#  'data/dacon/test_image/test_200129.jpg',
#  'data/dacon/test_image/test_200130.jpg',
#  'data/dacon/test_image/test_200131.jpg',
#  'data/dacon/test_image/test_200132.jpg',
#  'data/dacon/test_image/test_200133.jpg',
#  'data/dacon/test_image/test_200134.jpg',
#  'data/dacon/test_image/test_200135.jpg',
#  'data/dacon/test_image/test_200136.jpg',
#  'data/dacon/test_image/test_200137.jpg',
#  'data/dacon/test_image/test_200138.jpg',
#  'data/dacon/test_image/test_200139.jpg',
#  'data/dacon/test_image/test_200140.jpg',
#  'data/dacon/test_image/test_200141.jpg',
#  'data/dacon/test_image/test_200142.jpg',
#  'data/dacon/test_image/test_200143.jpg',
#  'data/dacon/test_image/test_200144.jpg',
#  'data/dacon/test_image/test_200145.jpg',
#  'data/dacon/test_image/test_200146.jpg',
#  'data/dacon/test_image/test_200147.jpg',
#  'data/dacon/test_image/test_200148.jpg',
#  'data/dacon/test_image/test_200149.jpg',
#  'data/dacon/test_image/test_200150.jpg',
#  'data/dacon/test_image/test_200151.jpg',
#  'data/dacon/test_image/test_200152.jpg',
#  'data/dacon/test_image/test_200153.jpg',
#  'data/dacon/test_image/test_200154.jpg',
#  'data/dacon/test_image/test_200155.jpg',
#  'data/dacon/test_image/test_200156.jpg',
#  'data/dacon/test_image/test_200157.jpg',
#  'data/dacon/test_image/test_200158.jpg',
#  'data/dacon/test_image/test_200159.jpg',
#  'data/dacon/test_image/test_200160.jpg',
#  'data/dacon/test_image/test_200161.jpg',
#  'data/dacon/test_image/test_200162.jpg',
#  'data/dacon/test_image/test_200163.jpg',
#  'data/dacon/test_image/test_200164.jpg',
#  'data/dacon/test_image/test_200165.jpg',
#  'data/dacon/test_image/test_200166.jpg',
#  'data/dacon/test_image/test_200167.jpg',
#  'data/dacon/test_image/test_200168.jpg',
#  'data/dacon/test_image/test_200169.jpg',
#  'data/dacon/test_image/test_200170.jpg',
#  'data/dacon/test_image/test_200171.jpg',
#  'data/dacon/test_image/test_200172.jpg',
#  'data/dacon/test_image/test_200173.jpg',
#  'data/dacon/test_image/test_200174.jpg',
#  'data/dacon/test_image/test_200175.jpg',
#  'data/dacon/test_image/test_200176.jpg',
#  'data/dacon/test_image/test_200177.jpg',
#  'data/dacon/test_image/test_200178.jpg',
#  'data/dacon/test_image/test_200179.jpg',
#  'data/dacon/test_image/test_200180.jpg',
#  'data/dacon/test_image/test_200181.jpg',
#  'data/dacon/test_image/test_200182.jpg',
#  'data/dacon/test_image/test_200183.jpg',
#  'data/dacon/test_image/test_200184.jpg',
#  'data/dacon/test_image/test_200185.jpg',
#  'data/dacon/test_image/test_200186.jpg',
#  'data/dacon/test_image/test_200187.jpg',
#  'data/dacon/test_image/test_200188.jpg',
#  'data/dacon/test_image/test_200189.jpg',
#  'data/dacon/test_image/test_200190.jpg',
#  'data/dacon/test_image/test_200191.jpg',
#  'data/dacon/test_image/test_200192.jpg',
#  'data/dacon/test_image/test_200193.jpg',
#  'data/dacon/test_image/test_200194.jpg',
#  'data/dacon/test_image/test_200195.jpg',
#  'data/dacon/test_image/test_200196.jpg',
#  'data/dacon/test_image/test_200197.jpg',
#  'data/dacon/test_image/test_200198.jpg',
#  'data/dacon/test_image/test_200199.jpg',
#  'data/dacon/test_image/test_200200.jpg',
#  'data/dacon/test_image/test_200201.jpg',
#  'data/dacon/test_image/test_200202.jpg',
#  'data/dacon/test_image/test_200203.jpg',
#  'data/dacon/test_image/test_200204.jpg',
#  'data/dacon/test_image/test_200205.jpg',
#  'data/dacon/test_image/test_200206.jpg',
#  'data/dacon/test_image/test_200207.jpg',
#  'data/dacon/test_image/test_200208.jpg',
#  'data/dacon/test_image/test_200209.jpg',
#  'data/dacon/test_image/test_200210.jpg',
#  'data/dacon/test_image/test_200211.jpg',
#  'data/dacon/test_image/test_200212.jpg',
#  'data/dacon/test_image/test_200213.jpg',
#  'data/dacon/test_image/test_200214.jpg',
#  'data/dacon/test_image/test_200215.jpg',
#  'data/dacon/test_image/test_200216.jpg',
#  'data/dacon/test_image/test_200217.jpg',
#  'data/dacon/test_image/test_200218.jpg',
#  'data/dacon/test_image/test_200219.jpg',
#  'data/dacon/test_image/test_200220.jpg',
#  'data/dacon/test_image/test_200221.jpg',
#  'data/dacon/test_image/test_200222.jpg',
#  'data/dacon/test_image/test_200223.jpg',
#  'data/dacon/test_image/test_200224.jpg',
#  'data/dacon/test_image/test_200225.jpg',
#  'data/dacon/test_image/test_200226.jpg',
#  'data/dacon/test_image/test_200227.jpg',
#  'data/dacon/test_image/test_200228.jpg',
#  'data/dacon/test_image/test_200229.jpg',
#  'data/dacon/test_image/test_200230.jpg',
#  'data/dacon/test_image/test_200231.jpg',
#  'data/dacon/test_image/test_200232.jpg',
#  'data/dacon/test_image/test_200233.jpg',
#  'data/dacon/test_image/test_200234.jpg',
#  'data/dacon/test_image/test_200235.jpg',
#  'data/dacon/test_image/test_200236.jpg',
#  'data/dacon/test_image/test_200237.jpg',
#  'data/dacon/test_image/test_200238.jpg',
#  'data/dacon/test_image/test_200239.jpg',
#  'data/dacon/test_image/test_200240.jpg',
#  'data/dacon/test_image/test_200241.jpg',
#  'data/dacon/test_image/test_200242.jpg',
#  'data/dacon/test_image/test_200243.jpg',
#  'data/dacon/test_image/test_200244.jpg',
#  'data/dacon/test_image/test_200245.jpg',
#  'data/dacon/test_image/test_200246.jpg',
#  'data/dacon/test_image/test_200247.jpg',
#  'data/dacon/test_image/test_200248.jpg',
#  'data/dacon/test_image/test_200249.jpg',
#  'data/dacon/test_image/test_200250.jpg',
#  'data/dacon/test_image/test_200251.jpg',
#  'data/dacon/test_image/test_200252.jpg',
#  'data/dacon/test_image/test_200253.jpg',
#  'data/dacon/test_image/test_200254.jpg',
#  'data/dacon/test_image/test_200255.jpg',
#  'data/dacon/test_image/test_200256.jpg',
#  'data/dacon/test_image/test_200257.jpg',
#  'data/dacon/test_image/test_200258.jpg',
#  'data/dacon/test_image/test_200259.jpg',
#  'data/dacon/test_image/test_200260.jpg',
#  'data/dacon/test_image/test_200261.jpg',
#  'data/dacon/test_image/test_200262.jpg',
#  'data/dacon/test_image/test_200263.jpg',
#  'data/dacon/test_image/test_200264.jpg',
#  'data/dacon/test_image/test_200265.jpg',
#  'data/dacon/test_image/test_200266.jpg',
#  'data/dacon/test_image/test_200267.jpg',
#  'data/dacon/test_image/test_200268.jpg',
#  'data/dacon/test_image/test_200269.jpg',
#  'data/dacon/test_image/test_200270.jpg',
#  'data/dacon/test_image/test_200271.jpg',
#  'data/dacon/test_image/test_200272.jpg',
#  'data/dacon/test_image/test_200273.jpg',
#  'data/dacon/test_image/test_200274.jpg',
#  'data/dacon/test_image/test_200275.jpg',
#  'data/dacon/test_image/test_200276.jpg',
#  'data/dacon/test_image/test_200277.jpg',
#  'data/dacon/test_image/test_200278.jpg',
#  'data/dacon/test_image/test_200279.jpg',
#  'data/dacon/test_image/test_200280.jpg',
#  'data/dacon/test_image/test_200281.jpg',
#  'data/dacon/test_image/test_200282.jpg',
#  'data/dacon/test_image/test_200283.jpg',
#  'data/dacon/test_image/test_200284.jpg',
#  'data/dacon/test_image/test_200285.jpg',
#  'data/dacon/test_image/test_200286.jpg',
#  'data/dacon/test_image/test_200287.jpg',
#  'data/dacon/test_image/test_200288.jpg',
#  'data/dacon/test_image/test_200289.jpg',
#  'data/dacon/test_image/test_200290.jpg',
#  'data/dacon/test_image/test_200291.jpg',
#  'data/dacon/test_image/test_200292.jpg',
#  'data/dacon/test_image/test_200293.jpg',
#  'data/dacon/test_image/test_200294.jpg',
#  'data/dacon/test_image/test_200295.jpg',
#  'data/dacon/test_image/test_200296.jpg',
#  'data/dacon/test_image/test_200297.jpg',
#  'data/dacon/test_image/test_200298.jpg',
#  'data/dacon/test_image/test_200299.jpg',
#  'data/dacon/test_image/test_200300.jpg',
#  'data/dacon/test_image/test_200301.jpg',
#  'data/dacon/test_image/test_200302.jpg',
#  'data/dacon/test_image/test_200303.jpg',
#  'data/dacon/test_image/test_200304.jpg',
#  'data/dacon/test_image/test_200305.jpg',
#  'data/dacon/test_image/test_200306.jpg',
#  'data/dacon/test_image/test_200307.jpg',
#  'data/dacon/test_image/test_200308.jpg',
#  'data/dacon/test_image/test_200309.jpg',
#  'data/dacon/test_image/test_200310.jpg',
#  'data/dacon/test_image/test_200311.jpg',
#  'data/dacon/test_image/test_200312.jpg',
#  'data/dacon/test_image/test_200313.jpg',
#  'data/dacon/test_image/test_200314.jpg',
#  'data/dacon/test_image/test_200315.jpg',
#  'data/dacon/test_image/test_200316.jpg',
#  'data/dacon/test_image/test_200317.jpg',
#  'data/dacon/test_image/test_200318.jpg',
#  'data/dacon/test_image/test_200319.jpg',
#  'data/dacon/test_image/test_200320.jpg',
#  'data/dacon/test_image/test_200321.jpg',
#  'data/dacon/test_image/test_200322.jpg',
#  'data/dacon/test_image/test_200323.jpg',
#  'data/dacon/test_image/test_200324.jpg',
#  'data/dacon/test_image/test_200325.jpg',
#  'data/dacon/test_image/test_200326.jpg',
#  'data/dacon/test_image/test_200327.jpg',
#  'data/dacon/test_image/test_200328.jpg',
#  'data/dacon/test_image/test_200329.jpg',
#  'data/dacon/test_image/test_200330.jpg',
#  'data/dacon/test_image/test_200331.jpg',
#  'data/dacon/test_image/test_200332.jpg',
#  'data/dacon/test_image/test_200333.jpg',
#  'data/dacon/test_image/test_200334.jpg',
#  'data/dacon/test_image/test_200335.jpg',
#  'data/dacon/test_image/test_200336.jpg',
#  'data/dacon/test_image/test_200337.jpg',
#  'data/dacon/test_image/test_200338.jpg',
#  'data/dacon/test_image/test_200339.jpg',
#  'data/dacon/test_image/test_200340.jpg',
#  'data/dacon/test_image/test_200341.jpg',
#  'data/dacon/test_image/test_200342.jpg',
#  'data/dacon/test_image/test_200343.jpg',
#  'data/dacon/test_image/test_200344.jpg',
#  'data/dacon/test_image/test_200345.jpg',
#  'data/dacon/test_image/test_200346.jpg',
#  'data/dacon/test_image/test_200347.jpg',
#  'data/dacon/test_image/test_200348.jpg',
#  'data/dacon/test_image/test_200349.jpg',
#  'data/dacon/test_image/test_200350.jpg',
#  'data/dacon/test_image/test_200351.jpg',
#  'data/dacon/test_image/test_200352.jpg',
#  'data/dacon/test_image/test_200353.jpg',
#  'data/dacon/test_image/test_200354.jpg',
#  'data/dacon/test_image/test_200355.jpg',
#  'data/dacon/test_image/test_200356.jpg',
#  'data/dacon/test_image/test_200357.jpg',
#  'data/dacon/test_image/test_200358.jpg',
#  'data/dacon/test_image/test_200359.jpg',
#  'data/dacon/test_image/test_200360.jpg',
#  'data/dacon/test_image/test_200361.jpg',
#  'data/dacon/test_image/test_200362.jpg',
#  'data/dacon/test_image/test_200363.jpg',
#  'data/dacon/test_image/test_200364.jpg',
#  'data/dacon/test_image/test_200365.jpg',
#  'data/dacon/test_image/test_200366.jpg',
#  'data/dacon/test_image/test_200367.jpg',
#  'data/dacon/test_image/test_200368.jpg',
#  'data/dacon/test_image/test_200369.jpg',
#  'data/dacon/test_image/test_200370.jpg',
#  'data/dacon/test_image/test_200371.jpg',
#  'data/dacon/test_image/test_200372.jpg',
#  'data/dacon/test_image/test_200373.jpg',
#  'data/dacon/test_image/test_200374.jpg',
#  'data/dacon/test_image/test_200375.jpg',
#  'data/dacon/test_image/test_200376.jpg',
#  'data/dacon/test_image/test_200377.jpg',
#  'data/dacon/test_image/test_200378.jpg',
#  'data/dacon/test_image/test_200379.jpg',
#  'data/dacon/test_image/test_200380.jpg',
#  'data/dacon/test_image/test_200381.jpg',
#  'data/dacon/test_image/test_200382.jpg',
#  'data/dacon/test_image/test_200383.jpg',
#  'data/dacon/test_image/test_200384.jpg',
#  'data/dacon/test_image/test_200385.jpg',
#  'data/dacon/test_image/test_200386.jpg',
#  'data/dacon/test_image/test_200387.jpg',
#  'data/dacon/test_image/test_200388.jpg',
#  'data/dacon/test_image/test_200389.jpg',
#  'data/dacon/test_image/test_200390.jpg',
#  'data/dacon/test_image/test_200391.jpg',
#  'data/dacon/test_image/test_200392.jpg',
#  'data/dacon/test_image/test_200393.jpg',
#  'data/dacon/test_image/test_200394.jpg',
#  'data/dacon/test_image/test_200395.jpg',
#  'data/dacon/test_image/test_200396.jpg',
#  'data/dacon/test_image/test_200397.jpg',
#  'data/dacon/test_image/test_200398.jpg',
#  'data/dacon/test_image/test_200399.jpg',
#  'data/dacon/test_image/test_200400.jpg',
#  'data/dacon/test_image/test_200401.jpg',
#  'data/dacon/test_image/test_200402.jpg',
#  'data/dacon/test_image/test_200403.jpg',
#  'data/dacon/test_image/test_200404.jpg',
#  'data/dacon/test_image/test_200405.jpg',
#  'data/dacon/test_image/test_200406.jpg',
#  'data/dacon/test_image/test_200407.jpg',
#  'data/dacon/test_image/test_200408.jpg',
#  'data/dacon/test_image/test_200409.jpg',
#  'data/dacon/test_image/test_200410.jpg',
#  'data/dacon/test_image/test_200411.jpg',
#  'data/dacon/test_image/test_200412.jpg',
#  'data/dacon/test_image/test_200413.jpg',
#  'data/dacon/test_image/test_200414.jpg',
#  'data/dacon/test_image/test_200415.jpg',
#  'data/dacon/test_image/test_200416.jpg',
#  'data/dacon/test_image/test_200417.jpg',
#  'data/dacon/test_image/test_200418.jpg',
#  'data/dacon/test_image/test_200419.jpg',
#  'data/dacon/test_image/test_200420.jpg',
#  'data/dacon/test_image/test_200421.jpg',
#  'data/dacon/test_image/test_200422.jpg',
#  'data/dacon/test_image/test_200423.jpg',
#  'data/dacon/test_image/test_200424.jpg',
#  'data/dacon/test_image/test_200425.jpg',
#  'data/dacon/test_image/test_200426.jpg',
#  'data/dacon/test_image/test_200427.jpg',
#  'data/dacon/test_image/test_200428.jpg',
#  'data/dacon/test_image/test_200429.jpg',
#  'data/dacon/test_image/test_200430.jpg',
#  'data/dacon/test_image/test_200431.jpg',
#  'data/dacon/test_image/test_200432.jpg',
#  'data/dacon/test_image/test_200433.jpg',
#  'data/dacon/test_image/test_200434.jpg',
#  'data/dacon/test_image/test_200435.jpg',
#  'data/dacon/test_image/test_200436.jpg',
#  'data/dacon/test_image/test_200437.jpg',
#  'data/dacon/test_image/test_200438.jpg',
#  'data/dacon/test_image/test_200439.jpg',
#  'data/dacon/test_image/test_200440.jpg',
#  'data/dacon/test_image/test_200441.jpg',
#  'data/dacon/test_image/test_200442.jpg',
#  'data/dacon/test_image/test_200443.jpg',
#  'data/dacon/test_image/test_200444.jpg',
#  'data/dacon/test_image/test_200445.jpg',
#  'data/dacon/test_image/test_200446.jpg',
#  'data/dacon/test_image/test_200447.jpg',
#  'data/dacon/test_image/test_200448.jpg',
#  'data/dacon/test_image/test_200449.jpg',
#  'data/dacon/test_image/test_200450.jpg',
#  'data/dacon/test_image/test_200451.jpg',
#  'data/dacon/test_image/test_200452.jpg',
#  'data/dacon/test_image/test_200453.jpg',
#  'data/dacon/test_image/test_200454.jpg',
#  'data/dacon/test_image/test_200455.jpg',
#  'data/dacon/test_image/test_200456.jpg',
#  'data/dacon/test_image/test_200457.jpg',
#  'data/dacon/test_image/test_200458.jpg',
#  'data/dacon/test_image/test_200459.jpg',
#  'data/dacon/test_image/test_200460.jpg',
#  'data/dacon/test_image/test_200461.jpg',
#  'data/dacon/test_image/test_200462.jpg',
#  'data/dacon/test_image/test_200463.jpg',
#  'data/dacon/test_image/test_200464.jpg',
#  'data/dacon/test_image/test_200465.jpg',
#  'data/dacon/test_image/test_200466.jpg',
#  'data/dacon/test_image/test_200467.jpg',
#  'data/dacon/test_image/test_200468.jpg',
#  'data/dacon/test_image/test_200469.jpg',
#  'data/dacon/test_image/test_200470.jpg',
#  'data/dacon/test_image/test_200471.jpg',
#  'data/dacon/test_image/test_200472.jpg',
#  'data/dacon/test_image/test_200473.jpg',
#  'data/dacon/test_image/test_200474.jpg',
#  'data/dacon/test_image/test_200475.jpg',
#  'data/dacon/test_image/test_200476.jpg',
#  'data/dacon/test_image/test_200477.jpg',
#  'data/dacon/test_image/test_200478.jpg',
#  'data/dacon/test_image/test_200479.jpg',
#  'data/dacon/test_image/test_200480.jpg',
#  'data/dacon/test_image/test_200481.jpg',
#  'data/dacon/test_image/test_200482.jpg',
#  'data/dacon/test_image/test_200483.jpg',
#  'data/dacon/test_image/test_200484.jpg',
#  'data/dacon/test_image/test_200485.jpg',
#  'data/dacon/test_image/test_200486.jpg',
#  'data/dacon/test_image/test_200487.jpg',
#  'data/dacon/test_image/test_200488.jpg',
#  'data/dacon/test_image/test_200489.jpg',
#  'data/dacon/test_image/test_200490.jpg',
#  'data/dacon/test_image/test_200491.jpg',
#  'data/dacon/test_image/test_200492.jpg',
#  'data/dacon/test_image/test_200493.jpg',
#  'data/dacon/test_image/test_200494.jpg',
#  'data/dacon/test_image/test_200495.jpg',
#  'data/dacon/test_image/test_200496.jpg',
#  'data/dacon/test_image/test_200497.jpg',
#  'data/dacon/test_image/test_200498.jpg',
#  'data/dacon/test_image/test_200499.jpg',
#  'data/dacon/test_image/test_200500.jpg',
#  'data/dacon/test_image/test_200501.jpg',
#  'data/dacon/test_image/test_200502.jpg',
#  'data/dacon/test_image/test_200503.jpg',
#  'data/dacon/test_image/test_200504.jpg',
#  'data/dacon/test_image/test_200505.jpg',
#  'data/dacon/test_image/test_200506.jpg',
#  'data/dacon/test_image/test_200507.jpg',
#  'data/dacon/test_image/test_200508.jpg',
#  'data/dacon/test_image/test_200509.jpg',
#  'data/dacon/test_image/test_200510.jpg',
#  'data/dacon/test_image/test_200511.jpg',
#  'data/dacon/test_image/test_200512.jpg',
#  'data/dacon/test_image/test_200513.jpg',
#  'data/dacon/test_image/test_200514.jpg',
#  'data/dacon/test_image/test_200515.jpg',
#  'data/dacon/test_image/test_200516.jpg',
#  'data/dacon/test_image/test_200517.jpg',
#  'data/dacon/test_image/test_200518.jpg',
#  'data/dacon/test_image/test_200519.jpg',
#  'data/dacon/test_image/test_200520.jpg',
#  'data/dacon/test_image/test_200521.jpg',
#  'data/dacon/test_image/test_200522.jpg',
#  'data/dacon/test_image/test_200523.jpg',
#  'data/dacon/test_image/test_200524.jpg',
#  'data/dacon/test_image/test_200525.jpg',
#  'data/dacon/test_image/test_200526.jpg',
#  'data/dacon/test_image/test_200527.jpg',
#  'data/dacon/test_image/test_200528.jpg',
#  'data/dacon/test_image/test_200529.jpg',
#  'data/dacon/test_image/test_200530.jpg',
#  'data/dacon/test_image/test_200531.jpg',
#  'data/dacon/test_image/test_200532.jpg',
#  'data/dacon/test_image/test_200533.jpg',
#  'data/dacon/test_image/test_200534.jpg',
#  'data/dacon/test_image/test_200535.jpg',
#  'data/dacon/test_image/test_200536.jpg',
#  'data/dacon/test_image/test_200537.jpg',
#  'data/dacon/test_image/test_200538.jpg',
#  'data/dacon/test_image/test_200539.jpg',
#  'data/dacon/test_image/test_200540.jpg',
#  'data/dacon/test_image/test_200541.jpg',
#  'data/dacon/test_image/test_200542.jpg',
#  'data/dacon/test_image/test_200543.jpg',
#  'data/dacon/test_image/test_200544.jpg',
#  'data/dacon/test_image/test_200545.jpg',
#  'data/dacon/test_image/test_200546.jpg',
#  'data/dacon/test_image/test_200547.jpg',
#  'data/dacon/test_image/test_200548.jpg',
#  'data/dacon/test_image/test_200549.jpg',
#  'data/dacon/test_image/test_200550.jpg',
#  'data/dacon/test_image/test_200551.jpg',
#  'data/dacon/test_image/test_200552.jpg',
#  'data/dacon/test_image/test_200553.jpg',
#  'data/dacon/test_image/test_200554.jpg',
#  'data/dacon/test_image/test_200555.jpg',
#  'data/dacon/test_image/test_200556.jpg',
#  'data/dacon/test_image/test_200557.jpg',
#  'data/dacon/test_image/test_200558.jpg',
#  'data/dacon/test_image/test_200559.jpg',
#  'data/dacon/test_image/test_200560.jpg',
#  'data/dacon/test_image/test_200561.jpg',
#  'data/dacon/test_image/test_200562.jpg',
#  'data/dacon/test_image/test_200563.jpg',
#  'data/dacon/test_image/test_200564.jpg',
#  'data/dacon/test_image/test_200565.jpg',
#  'data/dacon/test_image/test_200566.jpg',
#  'data/dacon/test_image/test_200567.jpg',
#  'data/dacon/test_image/test_200568.jpg',
#  'data/dacon/test_image/test_200569.jpg',
#  'data/dacon/test_image/test_200570.jpg',
#  'data/dacon/test_image/test_200571.jpg',
#  'data/dacon/test_image/test_200572.jpg',
#  'data/dacon/test_image/test_200573.jpg',
#  'data/dacon/test_image/test_200574.jpg',
#  'data/dacon/test_image/test_200575.jpg',
#  'data/dacon/test_image/test_200576.jpg',
#  'data/dacon/test_image/test_200577.jpg',
#  'data/dacon/test_image/test_200578.jpg',
#  'data/dacon/test_image/test_200579.jpg',
#  'data/dacon/test_image/test_200580.jpg',
#  'data/dacon/test_image/test_200581.jpg',
#  'data/dacon/test_image/test_200582.jpg',
#  'data/dacon/test_image/test_200583.jpg',
#  'data/dacon/test_image/test_200584.jpg',
#  'data/dacon/test_image/test_200585.jpg',
#  'data/dacon/test_image/test_200586.jpg',
#  'data/dacon/test_image/test_200587.jpg',
#  'data/dacon/test_image/test_200588.jpg',
#  'data/dacon/test_image/test_200589.jpg',
#  'data/dacon/test_image/test_200590.jpg',
#  'data/dacon/test_image/test_200591.jpg',
#  'data/dacon/test_image/test_200592.jpg',
#  'data/dacon/test_image/test_200593.jpg',
#  'data/dacon/test_image/test_200594.jpg',
#  'data/dacon/test_image/test_200595.jpg',
#  'data/dacon/test_image/test_200596.jpg',
#  'data/dacon/test_image/test_200597.jpg',
#  'data/dacon/test_image/test_200598.jpg',
#  'data/dacon/test_image/test_200599.jpg',
#  'data/dacon/test_image/test_200600.jpg',
#  'data/dacon/test_image/test_200601.jpg',
#  'data/dacon/test_image/test_200602.jpg',
#  'data/dacon/test_image/test_200603.jpg',
#  'data/dacon/test_image/test_200604.jpg',
#  'data/dacon/test_image/test_200605.jpg',
#  'data/dacon/test_image/test_200606.jpg',
#  'data/dacon/test_image/test_200607.jpg',
#  'data/dacon/test_image/test_200608.jpg',
#  'data/dacon/test_image/test_200609.jpg',
#  'data/dacon/test_image/test_200610.jpg',
#  'data/dacon/test_image/test_200611.jpg',
#  'data/dacon/test_image/test_200612.jpg',
#  'data/dacon/test_image/test_200613.jpg',
#  'data/dacon/test_image/test_200614.jpg',
#  'data/dacon/test_image/test_200615.jpg',
#  'data/dacon/test_image/test_200616.jpg',
#  'data/dacon/test_image/test_200617.jpg',
#  'data/dacon/test_image/test_200618.jpg',
#  'data/dacon/test_image/test_200619.jpg',
#  'data/dacon/test_image/test_200620.jpg',
#  'data/dacon/test_image/test_200621.jpg',
#  'data/dacon/test_image/test_200622.jpg',
#  'data/dacon/test_image/test_200623.jpg',
#  'data/dacon/test_image/test_200624.jpg',
#  'data/dacon/test_image/test_200625.jpg',
#  'data/dacon/test_image/test_200626.jpg',
#  'data/dacon/test_image/test_200627.jpg',
#  'data/dacon/test_image/test_200628.jpg',
#  'data/dacon/test_image/test_200629.jpg',
#  'data/dacon/test_image/test_200630.jpg',
#  'data/dacon/test_image/test_200631.jpg',
#  'data/dacon/test_image/test_200632.jpg',
#  'data/dacon/test_image/test_200633.jpg',
#  'data/dacon/test_image/test_200634.jpg',
#  'data/dacon/test_image/test_200635.jpg',
#  'data/dacon/test_image/test_200636.jpg',
#  'data/dacon/test_image/test_200637.jpg',
#  'data/dacon/test_image/test_200638.jpg',
#  'data/dacon/test_image/test_200639.jpg',
#  'data/dacon/test_image/test_200640.jpg',
#  'data/dacon/test_image/test_200641.jpg',
#  'data/dacon/test_image/test_200642.jpg',
#  'data/dacon/test_image/test_200643.jpg',
#  'data/dacon/test_image/test_200644.jpg',
#  'data/dacon/test_image/test_200645.jpg',
#  'data/dacon/test_image/test_200646.jpg',
#  'data/dacon/test_image/test_200647.jpg',
#  'data/dacon/test_image/test_200648.jpg',
#  'data/dacon/test_image/test_200649.jpg',
#  'data/dacon/test_image/test_200650.jpg',
#  'data/dacon/test_image/test_200651.jpg',
#  'data/dacon/test_image/test_200652.jpg',
#  'data/dacon/test_image/test_200653.jpg',
#  'data/dacon/test_image/test_200654.jpg',
#  'data/dacon/test_image/test_200655.jpg',
#  'data/dacon/test_image/test_200656.jpg',
#  'data/dacon/test_image/test_200657.jpg',
#  'data/dacon/test_image/test_200658.jpg',
#  'data/dacon/test_image/test_200659.jpg',
#  'data/dacon/test_image/test_200660.jpg',
#  'data/dacon/test_image/test_200661.jpg',
#  'data/dacon/test_image/test_200662.jpg',
#  'data/dacon/test_image/test_200663.jpg',
#  'data/dacon/test_image/test_200664.jpg',
#  'data/dacon/test_image/test_200665.jpg',
#  'data/dacon/test_image/test_200666.jpg',
#  'data/dacon/test_image/test_200667.jpg',
#  'data/dacon/test_image/test_200668.jpg',
#  'data/dacon/test_image/test_200669.jpg',
#  'data/dacon/test_image/test_200670.jpg',
#  'data/dacon/test_image/test_200671.jpg',
#  'data/dacon/test_image/test_200672.jpg',
#  'data/dacon/test_image/test_200673.jpg',
#  'data/dacon/test_image/test_200674.jpg',
#  'data/dacon/test_image/test_200675.jpg',
#  'data/dacon/test_image/test_200676.jpg',
#  'data/dacon/test_image/test_200677.jpg',
#  'data/dacon/test_image/test_200678.jpg',
#  'data/dacon/test_image/test_200679.jpg',
#  'data/dacon/test_image/test_200680.jpg',
#  'data/dacon/test_image/test_200681.jpg',
#  'data/dacon/test_image/test_200682.jpg',
#  'data/dacon/test_image/test_200683.jpg',
#  'data/dacon/test_image/test_200684.jpg',
#  'data/dacon/test_image/test_200685.jpg',
#  'data/dacon/test_image/test_200686.jpg',
#  'data/dacon/test_image/test_200687.jpg',
#  'data/dacon/test_image/test_200688.jpg',
#  'data/dacon/test_image/test_200689.jpg',
#  'data/dacon/test_image/test_200690.jpg',
#  'data/dacon/test_image/test_200691.jpg',
#  'data/dacon/test_image/test_200692.jpg',
#  'data/dacon/test_image/test_200693.jpg',
#  'data/dacon/test_image/test_200694.jpg',
#  'data/dacon/test_image/test_200695.jpg',
#  'data/dacon/test_image/test_200696.jpg',
#  'data/dacon/test_image/test_200697.jpg',
#  'data/dacon/test_image/test_200698.jpg',
#  'data/dacon/test_image/test_200699.jpg',
#  'data/dacon/test_image/test_200700.jpg',
#  'data/dacon/test_image/test_200701.jpg',
#  'data/dacon/test_image/test_200702.jpg',
#  'data/dacon/test_image/test_200703.jpg',
#  'data/dacon/test_image/test_200704.jpg',
#  'data/dacon/test_image/test_200705.jpg',
#  'data/dacon/test_image/test_200706.jpg',
#  'data/dacon/test_image/test_200707.jpg',
#  'data/dacon/test_image/test_200708.jpg',
#  'data/dacon/test_image/test_200709.jpg',
#  'data/dacon/test_image/test_200710.jpg',
#  'data/dacon/test_image/test_200711.jpg',
#  'data/dacon/test_image/test_200712.jpg',
#  'data/dacon/test_image/test_200713.jpg',
#  'data/dacon/test_image/test_200714.jpg',
#  'data/dacon/test_image/test_200715.jpg',
#  'data/dacon/test_image/test_200716.jpg',
#  'data/dacon/test_image/test_200717.jpg',
#  'data/dacon/test_image/test_200718.jpg',
#  'data/dacon/test_image/test_200719.jpg',
#  'data/dacon/test_image/test_200720.jpg',
#  'data/dacon/test_image/test_200721.jpg',
#  'data/dacon/test_image/test_200722.jpg',
#  'data/dacon/test_image/test_200723.jpg',
#  'data/dacon/test_image/test_200724.jpg',
#  'data/dacon/test_image/test_200725.jpg',
#  'data/dacon/test_image/test_200726.jpg',
#  'data/dacon/test_image/test_200727.jpg',
#  'data/dacon/test_image/test_200728.jpg',
#  'data/dacon/test_image/test_200729.jpg',
#  'data/dacon/test_image/test_200730.jpg',
#  'data/dacon/test_image/test_200731.jpg',
#  'data/dacon/test_image/test_200732.jpg',
#  'data/dacon/test_image/test_200733.jpg',
#  'data/dacon/test_image/test_200734.jpg',
#  'data/dacon/test_image/test_200735.jpg',
#  'data/dacon/test_image/test_200736.jpg',
#  'data/dacon/test_image/test_200737.jpg',
#  'data/dacon/test_image/test_200738.jpg',
#  'data/dacon/test_image/test_200739.jpg',
#  'data/dacon/test_image/test_200740.jpg',
#  'data/dacon/test_image/test_200741.jpg',
#  'data/dacon/test_image/test_200742.jpg',
#  'data/dacon/test_image/test_200743.jpg',
#  'data/dacon/test_image/test_200744.jpg',
#  'data/dacon/test_image/test_200745.jpg',
#  'data/dacon/test_image/test_200746.jpg',
#  'data/dacon/test_image/test_200747.jpg',
#  'data/dacon/test_image/test_200748.jpg',
#  'data/dacon/test_image/test_200749.jpg',
#  'data/dacon/test_image/test_200750.jpg',
#  'data/dacon/test_image/test_200751.jpg',
#  'data/dacon/test_image/test_200752.jpg',
#  'data/dacon/test_image/test_200753.jpg',
#  'data/dacon/test_image/test_200754.jpg',
#  'data/dacon/test_image/test_200755.jpg',
#  'data/dacon/test_image/test_200756.jpg',
#  'data/dacon/test_image/test_200757.jpg',
#  'data/dacon/test_image/test_200758.jpg',
#  'data/dacon/test_image/test_200759.jpg',
#  'data/dacon/test_image/test_200760.jpg',
#  'data/dacon/test_image/test_200761.jpg',
#  'data/dacon/test_image/test_200762.jpg',
#  'data/dacon/test_image/test_200763.jpg',
#  'data/dacon/test_image/test_200764.jpg',
#  'data/dacon/test_image/test_200765.jpg',
#  'data/dacon/test_image/test_200766.jpg',
#  'data/dacon/test_image/test_200767.jpg',
#  'data/dacon/test_image/test_200768.jpg',
#  'data/dacon/test_image/test_200769.jpg',
#  'data/dacon/test_image/test_200770.jpg',
#  'data/dacon/test_image/test_200771.jpg',
#  'data/dacon/test_image/test_200772.jpg',
#  'data/dacon/test_image/test_200773.jpg',
#  'data/dacon/test_image/test_200774.jpg',
#  'data/dacon/test_image/test_200775.jpg',
#  'data/dacon/test_image/test_200776.jpg',
#  'data/dacon/test_image/test_200777.jpg',
#  'data/dacon/test_image/test_200778.jpg',
#  'data/dacon/test_image/test_200779.jpg',
#  'data/dacon/test_image/test_200780.jpg',
#  'data/dacon/test_image/test_200781.jpg',
#  'data/dacon/test_image/test_200782.jpg',
#  'data/dacon/test_image/test_200783.jpg',
#  'data/dacon/test_image/test_200784.jpg',
#  'data/dacon/test_image/test_200785.jpg',
#  'data/dacon/test_image/test_200786.jpg',
#  'data/dacon/test_image/test_200787.jpg',
#  'data/dacon/test_image/test_200788.jpg',
#  'data/dacon/test_image/test_200789.jpg',
#  'data/dacon/test_image/test_200790.jpg',
#  'data/dacon/test_image/test_200791.jpg',
#  'data/dacon/test_image/test_200792.jpg',
#  'data/dacon/test_image/test_200793.jpg',
#  'data/dacon/test_image/test_200794.jpg',
#  'data/dacon/test_image/test_200795.jpg',
#  'data/dacon/test_image/test_200796.jpg',
#  'data/dacon/test_image/test_200797.jpg',
#  'data/dacon/test_image/test_200798.jpg',
#  'data/dacon/test_image/test_200799.jpg',
#  'data/dacon/test_image/test_200800.jpg',
#  'data/dacon/test_image/test_200801.jpg',
#  'data/dacon/test_image/test_200802.jpg',
#  'data/dacon/test_image/test_200803.jpg',
#  'data/dacon/test_image/test_200804.jpg',
#  'data/dacon/test_image/test_200805.jpg',
#  'data/dacon/test_image/test_200806.jpg',
#  'data/dacon/test_image/test_200807.jpg',
#  'data/dacon/test_image/test_200808.jpg',
#  'data/dacon/test_image/test_200809.jpg',
#  'data/dacon/test_image/test_200810.jpg',
#  'data/dacon/test_image/test_200811.jpg',
#  'data/dacon/test_image/test_200812.jpg',
#  'data/dacon/test_image/test_200813.jpg',
#  'data/dacon/test_image/test_200814.jpg',
#  'data/dacon/test_image/test_200815.jpg',
#  'data/dacon/test_image/test_200816.jpg',
#  'data/dacon/test_image/test_200817.jpg',
#  'data/dacon/test_image/test_200818.jpg',
#  'data/dacon/test_image/test_200819.jpg',
#  'data/dacon/test_image/test_200820.jpg',
#  'data/dacon/test_image/test_200821.jpg',
#  'data/dacon/test_image/test_200822.jpg',
#  'data/dacon/test_image/test_200823.jpg',
#  'data/dacon/test_image/test_200824.jpg',
#  'data/dacon/test_image/test_200825.jpg',
#  'data/dacon/test_image/test_200826.jpg',
#  'data/dacon/test_image/test_200827.jpg',
#  'data/dacon/test_image/test_200828.jpg',
#  'data/dacon/test_image/test_200829.jpg',
#  'data/dacon/test_image/test_200830.jpg',
#  'data/dacon/test_image/test_200831.jpg',
#  'data/dacon/test_image/test_200832.jpg',
#  'data/dacon/test_image/test_200833.jpg',
#  'data/dacon/test_image/test_200834.jpg',
#  'data/dacon/test_image/test_200835.jpg',
#  'data/dacon/test_image/test_200836.jpg',
#  'data/dacon/test_image/test_200837.jpg',
#  'data/dacon/test_image/test_200838.jpg',
#  'data/dacon/test_image/test_200839.jpg',
#  'data/dacon/test_image/test_200840.jpg',
#  'data/dacon/test_image/test_200841.jpg',
#  'data/dacon/test_image/test_200842.jpg',
#  'data/dacon/test_image/test_200843.jpg',
#  'data/dacon/test_image/test_200844.jpg',
#  'data/dacon/test_image/test_200845.jpg',
#  'data/dacon/test_image/test_200846.jpg',
#  'data/dacon/test_image/test_200847.jpg',
#  'data/dacon/test_image/test_200848.jpg',
#  'data/dacon/test_image/test_200849.jpg',
#  'data/dacon/test_image/test_200850.jpg',
#  'data/dacon/test_image/test_200851.jpg',
#  'data/dacon/test_image/test_200852.jpg',
#  'data/dacon/test_image/test_200853.jpg',
#  'data/dacon/test_image/test_200854.jpg',
#  'data/dacon/test_image/test_200855.jpg',
#  'data/dacon/test_image/test_200856.jpg',
#  'data/dacon/test_image/test_200857.jpg',
#  'data/dacon/test_image/test_200858.jpg',
#  'data/dacon/test_image/test_200859.jpg',
#  'data/dacon/test_image/test_200860.jpg',
#  'data/dacon/test_image/test_200861.jpg',
#  'data/dacon/test_image/test_200862.jpg',
#  'data/dacon/test_image/test_200863.jpg',
#  'data/dacon/test_image/test_200864.jpg',
#  'data/dacon/test_image/test_200865.jpg',
#  'data/dacon/test_image/test_200866.jpg',
#  'data/dacon/test_image/test_200867.jpg',
#  'data/dacon/test_image/test_200868.jpg',
#  'data/dacon/test_image/test_200869.jpg',
#  'data/dacon/test_image/test_200870.jpg',
#  'data/dacon/test_image/test_200871.jpg',
#  'data/dacon/test_image/test_200872.jpg',
#  'data/dacon/test_image/test_200873.jpg',
#  'data/dacon/test_image/test_200874.jpg',
#  'data/dacon/test_image/test_200875.jpg',
#  'data/dacon/test_image/test_200876.jpg',
#  'data/dacon/test_image/test_200877.jpg',
#  'data/dacon/test_image/test_200878.jpg',
#  'data/dacon/test_image/test_200879.jpg',
#  'data/dacon/test_image/test_200880.jpg',
#  'data/dacon/test_image/test_200881.jpg',
#  'data/dacon/test_image/test_200882.jpg',
#  'data/dacon/test_image/test_200883.jpg',
#  'data/dacon/test_image/test_200884.jpg',
#  'data/dacon/test_image/test_200885.jpg',
#  'data/dacon/test_image/test_200886.jpg',
#  'data/dacon/test_image/test_200887.jpg',
#  'data/dacon/test_image/test_200888.jpg',
#  'data/dacon/test_image/test_200889.jpg',
#  'data/dacon/test_image/test_200890.jpg',
#  'data/dacon/test_image/test_200891.jpg',
#  'data/dacon/test_image/test_200892.jpg',
#  'data/dacon/test_image/test_200893.jpg',
#  'data/dacon/test_image/test_200894.jpg',
#  'data/dacon/test_image/test_200895.jpg',
#  'data/dacon/test_image/test_200896.jpg',
#  'data/dacon/test_image/test_200897.jpg',
#  'data/dacon/test_image/test_200898.jpg',
#  'data/dacon/test_image/test_200899.jpg',
#  'data/dacon/test_image/test_200900.jpg',
#  'data/dacon/test_image/test_200901.jpg',
#  'data/dacon/test_image/test_200902.jpg',
#  'data/dacon/test_image/test_200903.jpg',
#  'data/dacon/test_image/test_200904.jpg',
#  'data/dacon/test_image/test_200905.jpg',
#  'data/dacon/test_image/test_200906.jpg',
#  'data/dacon/test_image/test_200907.jpg',
#  'data/dacon/test_image/test_200908.jpg',
#  'data/dacon/test_image/test_200909.jpg',
#  'data/dacon/test_image/test_200910.jpg',
#  'data/dacon/test_image/test_200911.jpg',
#  'data/dacon/test_image/test_200912.jpg',
#  'data/dacon/test_image/test_200913.jpg',
#  'data/dacon/test_image/test_200914.jpg',
#  'data/dacon/test_image/test_200915.jpg',
#  'data/dacon/test_image/test_200916.jpg',
#  'data/dacon/test_image/test_200917.jpg',
#  'data/dacon/test_image/test_200918.jpg',
#  'data/dacon/test_image/test_200919.jpg',
#  'data/dacon/test_image/test_200920.jpg',
#  'data/dacon/test_image/test_200921.jpg',
#  'data/dacon/test_image/test_200922.jpg',
#  'data/dacon/test_image/test_200923.jpg',
#  'data/dacon/test_image/test_200924.jpg',
#  'data/dacon/test_image/test_200925.jpg',
#  'data/dacon/test_image/test_200926.jpg',
#  'data/dacon/test_image/test_200927.jpg',
#  'data/dacon/test_image/test_200928.jpg',
#  'data/dacon/test_image/test_200929.jpg',
#  'data/dacon/test_image/test_200930.jpg',
#  'data/dacon/test_image/test_200931.jpg',
#  'data/dacon/test_image/test_200932.jpg',
#  'data/dacon/test_image/test_200933.jpg',
#  'data/dacon/test_image/test_200934.jpg',
#  'data/dacon/test_image/test_200935.jpg',
#  'data/dacon/test_image/test_200936.jpg',
#  'data/dacon/test_image/test_200937.jpg',
#  'data/dacon/test_image/test_200938.jpg',
#  'data/dacon/test_image/test_200939.jpg',
#  'data/dacon/test_image/test_200940.jpg',
#  'data/dacon/test_image/test_200941.jpg',
#  'data/dacon/test_image/test_200942.jpg',
#  'data/dacon/test_image/test_200943.jpg',
#  'data/dacon/test_image/test_200944.jpg',
#  'data/dacon/test_image/test_200945.jpg',
#  'data/dacon/test_image/test_200946.jpg',
#  'data/dacon/test_image/test_200947.jpg',
#  'data/dacon/test_image/test_200948.jpg',
#  'data/dacon/test_image/test_200949.jpg',
#  'data/dacon/test_image/test_200950.jpg',
#  'data/dacon/test_image/test_200951.jpg',
#  'data/dacon/test_image/test_200952.jpg',
#  'data/dacon/test_image/test_200953.jpg',
#  'data/dacon/test_image/test_200954.jpg',
#  'data/dacon/test_image/test_200955.jpg',
#  'data/dacon/test_image/test_200956.jpg',
#  'data/dacon/test_image/test_200957.jpg',
#  'data/dacon/test_image/test_200958.jpg',
#  'data/dacon/test_image/test_200959.jpg',
#  'data/dacon/test_image/test_200960.jpg',
#  'data/dacon/test_image/test_200961.jpg',
#  'data/dacon/test_image/test_200962.jpg',
#  'data/dacon/test_image/test_200963.jpg',
#  'data/dacon/test_image/test_200964.jpg',
#  'data/dacon/test_image/test_200965.jpg',
#  'data/dacon/test_image/test_200966.jpg',
#  'data/dacon/test_image/test_200967.jpg',
#  'data/dacon/test_image/test_200968.jpg',
#  'data/dacon/test_image/test_200969.jpg',
#  'data/dacon/test_image/test_200970.jpg',
#  'data/dacon/test_image/test_200971.jpg',
#  'data/dacon/test_image/test_200972.jpg',
#  'data/dacon/test_image/test_200973.jpg',
#  'data/dacon/test_image/test_200974.jpg',
#  'data/dacon/test_image/test_200975.jpg',
#  'data/dacon/test_image/test_200976.jpg',
#  'data/dacon/test_image/test_200977.jpg',
#  'data/dacon/test_image/test_200978.jpg',
#  'data/dacon/test_image/test_200979.jpg',
#  'data/dacon/test_image/test_200980.jpg',
#  'data/dacon/test_image/test_200981.jpg',
#  'data/dacon/test_image/test_200982.jpg',
#  'data/dacon/test_image/test_200983.jpg',
#  'data/dacon/test_image/test_200984.jpg',
#  'data/dacon/test_image/test_200985.jpg',
#  'data/dacon/test_image/test_200986.jpg',
#  'data/dacon/test_image/test_200987.jpg',
#  'data/dacon/test_image/test_200988.jpg',
#  'data/dacon/test_image/test_200989.jpg',
#  'data/dacon/test_image/test_200990.jpg',
#  'data/dacon/test_image/test_200991.jpg',
#  'data/dacon/test_image/test_200992.jpg',
#  'data/dacon/test_image/test_200993.jpg',
#  'data/dacon/test_image/test_200994.jpg',
#  'data/dacon/test_image/test_200995.jpg',
#  'data/dacon/test_image/test_200996.jpg',
#  'data/dacon/test_image/test_200997.jpg',
#  'data/dacon/test_image/test_200998.jpg',
#  'data/dacon/test_image/test_200999.jpg',
#  ...]

# %%
with open('data/dacon/test_annotations.json', 'r') as temp:
    output = json.load(temp)

# %%
output.keys()
# Out:
# dict_keys(['images', 'annotations', 'categories'])

# %%
    # init distributed env first, since logger depends on the dist info.
    if args.launcher == 'none':
        distributed = False
    else:
        distributed = True
        init_dist(args.launcher, **cfg.dist_params)

    rank, _ = get_dist_info()
    # allows not to create
    if args.work_dir is not None and rank == 0:
        mmcv.mkdir_or_exist(osp.abspath(args.work_dir))
        timestamp = time.strftime('%Y%m%d_%H%M%S', time.localtime())
        json_file = osp.join(args.work_dir, f'eval_{timestamp}.json')

    # build the dataloader
    dataset = build_dataset(cfg.data.test)
    data_loader = build_dataloader(
        dataset,
        samples_per_gpu=samples_per_gpu,
        workers_per_gpu=cfg.data.workers_per_gpu,
        dist=distributed,
        shuffle=False)

# %%
cfg.data.test
# Out:
# {'type': 'CocoDataset',
#  'ann_file': 'data/coco/annotations/instances_val2017.json',
#  'img_prefix': 'data/dacon/test_image/',
#  'pipeline': [{'type': 'LoadImageFromFile'},
#   {'type': 'MultiScaleFlipAug',
#    'img_scale': (1333, 800),
#    'flip': True,
#    'transforms': [{'type': 'Resize', 'keep_ratio': True},
#     {'type': 'RandomFlip'},
#     {'type': 'Normalize',
#      'mean': [123.675, 116.28, 103.53],
#      'std': [58.395, 57.12, 57.375],
#      'to_rgb': True},
#     {'type': 'Pad', 'size_divisor': 32},
#     {'type': 'ImageToTensor', 'keys': ['img']},
#     {'type': 'Collect', 'keys': ['img']}]}],
#  'classes': ('01_ulcer', '02_mass', '04_lymph', '05_bleeding')}

# %%
if args.cfg_options is not None:
    cfg.merge_from_dict(args.cfg_options)
# import modules from string list.
if cfg.get('custom_imports', None):
    from mmcv.utils import import_modules_from_strings
    import_modules_from_strings(**cfg['custom_imports'])
# set cudnn_benchmark
if cfg.get('cudnn_benchmark', False):
    torch.backends.cudnn.benchmark = True

# work_dir is determined in this priority: CLI > segment in file > filename
if args.work_dir is not None:
    # update configs according to CLI args if args.work_dir is not None
    cfg.work_dir = args.work_dir
elif cfg.get('work_dir', None) is None:
    # use config filename as default work_dir if cfg.work_dir is None
    cfg.work_dir = osp.join('./work_dirs',
                            osp.splitext(osp.basename(config))[0])
if args.resume_from is not None:
    cfg.resume_from = args.resume_from
if args.gpu_ids is not None:
    cfg.gpu_ids = args.gpu_ids
else:
    cfg.gpu_ids = range(1) if args.gpus is None else range(args.gpus)

# init distributed env first, since logger depends on the dist info.
if args.launcher == 'none':
    distributed = False
else:
    distributed = True
    init_dist(args.launcher, **cfg.dist_params)
    # re-set gpu_ids with distributed training mode
    _, world_size = get_dist_info()
    cfg.gpu_ids = range(world_size)

# %%
# create work_dir
mmcv.mkdir_or_exist(osp.abspath(cfg.work_dir))
# dump config
cfg.dump(osp.join(cfg.work_dir, osp.basename(config)))
# init the logger before other steps
timestamp = time.strftime('%Y%m%d_%H%M%S', time.localtime())
log_file = osp.join(cfg.work_dir, f'{timestamp}.log')
logger = get_root_logger(log_file=log_file, log_level=cfg.log_level)

# init the meta dict to record some important information such as
# environment info and seed, which will be logged
meta = dict()
# log env info
env_info_dict = collect_env()
env_info = '\n'.join([(f'{k}: {v}') for k, v in env_info_dict.items()])
dash_line = '-' * 60 + '\n'
logger.info('Environment info:\n' + dash_line + env_info + '\n' +
            dash_line)
meta['env_info'] = env_info
meta['config'] = cfg.pretty_text
# log some basic info
logger.info(f'Distributed training: {distributed}')
logger.info(f'Config:\n{cfg.pretty_text}')

# set random seeds
deterministic=False

seed = init_random_seed(777)
logger.info(f'Set random seed to {seed}, '
            f'deterministic: {deterministic}')
set_random_seed(seed, deterministic=deterministic)
cfg.seed = seed
meta['seed'] = seed
meta['exp_name'] = osp.basename(config)
# Out:
# 2021-11-17 15:49:56,795 - mmdet - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.7.11 (default, Jul 27 2021, 14:32:16) [GCC 7.5.0]
# CUDA available: False
# GCC: gcc (Ubuntu 9.3.0-17ubuntu1~20.04) 9.3.0
# PyTorch: 1.10.0+cu102
# PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.2 Product Build 20200624 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=10.2, CUDNN_VERSION=7.6.5, CXX_COMPILER=/opt/rh/devtoolset-7/root/usr/bin/c++, CXX_FLAGS= -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-sign-compare -Wno-unused-parameter -Wno-unused-variable -Wno-unused-function -Wno-unused-result -Wno-unused-local-typedefs -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.10.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON,
#
# TorchVision: 0.11.1+cu102
# OpenCV: 4.5.3
# MMCV: 1.3.17
# MMCV Compiler: GCC 7.3
# MMCV CUDA Compiler: 10.2
# MMDetection: 2.18.1+c76ab0e
# ------------------------------------------------------------
#
# 2021-11-17 15:49:57,037 - mmdet - INFO - Distributed training: False
# 2021-11-17 15:49:57,421 - mmdet - INFO - Config:
# model = dict(
#     type='FasterRCNN',
#     backbone=dict(
#         type='ResNet',
#         depth=50,
#         num_stages=4,
#         out_indices=(0, 1, 2, 3),
#         frozen_stages=1,
#         norm_cfg=dict(type='BN', requires_grad=True),
#         norm_eval=True,
#         style='pytorch',
#         init_cfg=dict(type='Pretrained', checkpoint='torchvision://resnet50')),
#     neck=dict(
#         type='FPN',
#         in_channels=[256, 512, 1024, 2048],
#         out_channels=256,
#         num_outs=5),
#     rpn_head=dict(
#         type='RPNHead',
#         in_channels=256,
#         feat_channels=256,
#         anchor_generator=dict(
#             type='AnchorGenerator',
#             scales=[8],
#             ratios=[0.5, 1.0, 2.0],
#             strides=[4, 8, 16, 32, 64]),
#         bbox_coder=dict(
#             type='DeltaXYWHBBoxCoder',
#             target_means=[0.0, 0.0, 0.0, 0.0],
#             target_stds=[1.0, 1.0, 1.0, 1.0]),
#         loss_cls=dict(
#             type='CrossEntropyLoss', use_sigmoid=True, loss_weight=1.0),
#         loss_bbox=dict(type='L1Loss', loss_weight=1.0)),
#     roi_head=dict(
#         type='StandardRoIHead',
#         bbox_roi_extractor=dict(
#             type='SingleRoIExtractor',
#             roi_layer=dict(type='RoIAlign', output_size=7, sampling_ratio=0),
#             out_channels=256,
#             featmap_strides=[4, 8, 16, 32]),
#         bbox_head=dict(
#             type='Shared2FCBBoxHead',
#             in_channels=256,
#             fc_out_channels=1024,
#             roi_feat_size=7,
#             num_classes=80,
#             bbox_coder=dict(
#                 type='DeltaXYWHBBoxCoder',
#                 target_means=[0.0, 0.0, 0.0, 0.0],
#                 target_stds=[0.1, 0.1, 0.2, 0.2]),
#             reg_class_agnostic=False,
#             loss_cls=dict(
#                 type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0),
#             loss_bbox=dict(type='L1Loss', loss_weight=1.0))),
#     train_cfg=dict(
#         rpn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.7,
#                 neg_iou_thr=0.3,
#                 min_pos_iou=0.3,
#                 match_low_quality=True,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=256,
#                 pos_fraction=0.5,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=False),
#             allowed_border=-1,
#             pos_weight=-1,
#             debug=False),
#         rpn_proposal=dict(
#             nms_pre=2000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.5,
#                 neg_iou_thr=0.5,
#                 min_pos_iou=0.5,
#                 match_low_quality=False,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=512,
#                 pos_fraction=0.25,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=True),
#             pos_weight=-1,
#             debug=False)),
#     test_cfg=dict(
#         rpn=dict(
#             nms_pre=1000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             score_thr=0.05,
#             nms=dict(type='nms', iou_threshold=0.5),
#             max_per_img=100)))
# dataset_type = 'COCODataset'
# data_root = 'data/coco/'
# img_norm_cfg = dict(
#     mean=[123.675, 116.28, 103.53], std=[58.395, 57.12, 57.375], to_rgb=True)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(type='Resize', img_scale=(1333, 800), keep_ratio=True),
#     dict(type='RandomFlip', flip_ratio=0.5),
#     dict(
#         type='Normalize',
#         mean=[123.675, 116.28, 103.53],
#         std=[58.395, 57.12, 57.375],
#         to_rgb=True),
#     dict(type='Pad', size_divisor=32),
#     dict(type='DefaultFormatBundle'),
#     dict(type='Collect', keys=['img', 'gt_bboxes', 'gt_labels'])
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(
#         type='MultiScaleFlipAug',
#         img_scale=(1333, 800),
#         flip=False,
#         transforms=[
#             dict(type='Resize', keep_ratio=True),
#             dict(type='RandomFlip'),
#             dict(
#                 type='Normalize',
#                 mean=[123.675, 116.28, 103.53],
#                 std=[58.395, 57.12, 57.375],
#                 to_rgb=True),
#             dict(type='Pad', size_divisor=32),
#             dict(type='ImageToTensor', keys=['img']),
#             dict(type='Collect', keys=['img'])
#         ])
# ]
# data = dict(
#     samples_per_gpu=2,
#     workers_per_gpu=2,
#     train=dict(
#         type='CocoDataset',
#         ann_file='data/dacon/train/train_annotations4.json',
#         img_prefix='data/dacon/train/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(type='Resize', img_scale=(1333, 800), keep_ratio=True),
#             dict(type='RandomFlip', flip_ratio=0.5),
#             dict(
#                 type='Normalize',
#                 mean=[123.675, 116.28, 103.53],
#                 std=[58.395, 57.12, 57.375],
#                 to_rgb=True),
#             dict(type='Pad', size_divisor=32),
#             dict(type='DefaultFormatBundle'),
#             dict(type='Collect', keys=['img', 'gt_bboxes', 'gt_labels'])
#         ],
#         classes=('01_ulcer', '02_mass', '04_lymph', '05_bleeding')),
#     val=dict(
#         type='CocoDataset',
#         ann_file='data/dacon/val/val_annotations4.json',
#         img_prefix='data/dacon/val/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(1333, 800),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[123.675, 116.28, 103.53],
#                         std=[58.395, 57.12, 57.375],
#                         to_rgb=True),
#                     dict(type='Pad', size_divisor=32),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ],
#         classes=('01_ulcer', '02_mass', '04_lymph', '05_bleeding')),
#     test=dict(
#         type='CocoDataset',
#         ann_file='data/dacon/val/val_annotations4.json',
#         img_prefix='data/dacon/val/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(1333, 800),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[123.675, 116.28, 103.53],
#                         std=[58.395, 57.12, 57.375],
#                         to_rgb=True),
#                     dict(type='Pad', size_divisor=32),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ],
#         classes=('01_ulcer', '02_mass', '04_lymph', '05_bleeding')))
# evaluation = dict(interval=1, metric='bbox')
# optimizer = dict(type='SGD', lr=0.02, momentum=0.9, weight_decay=0.0001)
# optimizer_config = dict(grad_clip=None)
# lr_config = dict(
#     policy='step',
#     warmup='linear',
#     warmup_iters=500,
#     warmup_ratio=0.001,
#     step=[8, 11])
# runner = dict(type='EpochBasedRunner', max_epochs=12)
# checkpoint_config = dict(interval=1)
# log_config = dict(interval=50, hooks=[dict(type='TextLoggerHook')])
# custom_hooks = [dict(type='NumClassCheckHook')]
# dist_params = dict(backend='nccl')
# log_level = 'INFO'
# load_from = None
# resume_from = None
# workflow = [('train', 1)]
# classes = ('01_ulcer', '02_mass', '04_lymph', '05_bleeding')
# work_dir = './work_dirs/faster_rcnn_r50_caffe_fpn_mstrain-poly_1x_balloon_dacon'
# gpu_ids = range(0, 1)
# 2021-11-17 15:49:57,423 - mmdet - INFO - Set random seed to 777, deterministic: False

# %%
model = build_detector(
    cfg.model,
    train_cfg=cfg.get('train_cfg'),
    test_cfg=cfg.get('test_cfg'))
model.init_weights()
# Out:
# 2021-11-17 15:49:57,765 - mmdet - INFO - initialize ResNet with init_cfg {'type': 'Pretrained', 'checkpoint': 'torchvision://resnet50'}
# 2021-11-17 15:49:57,767 - mmcv - INFO - load model from: torchvision://resnet50
# 2021-11-17 15:49:57,768 - mmcv - INFO - load checkpoint from torchvision path: torchvision://resnet50
# 2021-11-17 15:49:57,967 - mmcv - WARNING - The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: fc.weight, fc.bias
#
# 2021-11-17 15:49:57,983 - mmdet - INFO - initialize FPN with init_cfg {'type': 'Xavier', 'layer': 'Conv2d', 'distribution': 'uniform'}
# 2021-11-17 15:49:58,009 - mmdet - INFO - initialize RPNHead with init_cfg {'type': 'Normal', 'layer': 'Conv2d', 'std': 0.01}
# 2021-11-17 15:49:58,015 - mmdet - INFO - initialize Shared2FCBBoxHead with init_cfg [{'type': 'Normal', 'std': 0.01, 'override': {'name': 'fc_cls'}}, {'type': 'Normal', 'std': 0.001, 'override': {'name': 'fc_reg'}}, {'type': 'Xavier', 'override': [{'name': 'shared_fcs'}, {'name': 'cls_fcs'}, {'name': 'reg_fcs'}]}]

# %%
datasets = [build_dataset(cfg.data.train)]
# Out:
# loading annotations into memory...
# Done (t=0.46s)
# creating index...
# index created!

# %%
datasets
# Out:
# [
#  CocoDataset Train dataset with number of images 50098, and instance counts:
#  +--------------+-------+-------------+-------+--------------+-------+-----------------+-------+---------------+-------+
#  | category     | count | category    | count | category     | count | category        | count | category      | count |
#  +--------------+-------+-------------+-------+--------------+-------+-----------------+-------+---------------+-------+
#  | 0 [01_ulcer] | 21925 | 1 [02_mass] | 6858  | 2 [04_lymph] | 8220  | 3 [05_bleeding] | 13095 | -1 background | 0     |
#  +--------------+-------+-------------+-------+--------------+-------+-----------------+-------+---------------+-------+]

# %%
GroupSampler(datasets)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-40-54229404f285> in <module>
# ----> 1 GroupSampler(datasets)
#
# <ipython-input-34-faef69969dfb> in __init__(self, dataset, samples_per_gpu)
#       5
#       6     def __init__(self, dataset, samples_per_gpu=1):
# ----> 7         assert hasattr(dataset, 'flag')
#       8         self.dataset = dataset
#       9         self.samples_per_gpu = samples_per_gpu
#
# AssertionError:

# %%
cfg.data.train['type']
# Out:
# 'CocoDataset'

# %%
isinstance(cfg.data.train, (list, tuple))
# Out:
# False

# %%
from mmcv.utils import Registry, build_from_cfg

# %%
build_from_cfg(cfg.data.train)

# %%
cfg.data.train
# Out:
# {'type': 'CocoDataset',
#  'ann_file': 'data/dacon/train/train_annotations4.json',
#  'img_prefix': 'data/dacon/train/',
#  'pipeline': [{'type': 'LoadImageFromFile'},
#   {'type': 'LoadAnnotations', 'with_bbox': True},
#   {'type': 'Resize', 'img_scale': (1333, 800), 'keep_ratio': True},
#   {'type': 'RandomFlip', 'flip_ratio': 0.5},
#   {'type': 'Normalize',
#    'mean': [123.675, 116.28, 103.53],
#    'std': [58.395, 57.12, 57.375],
#    'to_rgb': True},
#   {'type': 'Pad', 'size_divisor': 32},
#   {'type': 'DefaultFormatBundle'},
#   {'type': 'Collect', 'keys': ['img', 'gt_bboxes', 'gt_labels']}],
#  'classes': ('01_ulcer', '02_mass', '04_lymph', '05_bleeding')}

# %%
from torch.utils.data import Sampler


class GroupSampler(Sampler):

    def __init__(self, dataset, samples_per_gpu=1):
        assert hasattr(dataset, 'flag')
        self.dataset = dataset
        self.samples_per_gpu = samples_per_gpu
        self.flag = dataset.flag.astype(np.int64)
        self.group_sizes = np.bincount(self.flag)
        self.num_samples = 0
        for i, size in enumerate(self.group_sizes):
            self.num_samples += int(np.ceil(
                size / self.samples_per_gpu)) * self.samples_per_gpu

    def __iter__(self):
        indices = []
        for i, size in enumerate(self.group_sizes):
            if size == 0:
                continue
            indice = np.where(self.flag == i)[0]
            assert len(indice) == size
            np.random.shuffle(indice)
            num_extra = int(np.ceil(size / self.samples_per_gpu)
                            ) * self.samples_per_gpu - len(indice)
            indice = np.concatenate(
                [indice, np.random.choice(indice, num_extra)])
            indices.append(indice)
        indices = np.concatenate(indices)
        indices = [
            indices[i * self.samples_per_gpu:(i + 1) * self.samples_per_gpu]
            for i in np.random.permutation(
                range(len(indices) // self.samples_per_gpu))
        ]
        indices = np.concatenate(indices)
        indices = indices.astype(np.int64).tolist()
        assert len(indices) == self.num_samples
        return iter(indices)

    def __len__(self):
        return self.num_samples

# %%
if len(cfg.workflow) == 2:
    val_dataset = copy.deepcopy(cfg.data.val)
    val_dataset.pipeline = cfg.data.train.pipeline
    datasets.append(build_dataset(val_dataset))
if cfg.checkpoint_config is not None:
    # save mmdet version, config file content and class names in
    # checkpoints as meta data
    cfg.checkpoint_config.meta = dict(
        mmdet_version=__version__ + get_git_hash()[:7],
        CLASSES=datasets[0].CLASSES)

# %%
# add an attribute for visualization convenience
model.CLASSES = datasets[0].CLASSES
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-ade82845ac07> in <module>
#       1 # add an attribute for visualization convenience
# ----> 2 model.CLASSES = datasets[0].CLASSES
#
# NameError: name 'datasets' is not defined

# %%
train_detector(
    model,
    datasets,
    cfg,
    distributed=distributed,
    validate=(not args.no_validate),
    timestamp=timestamp,
    meta=meta)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-22-0f98a392cd5d> in <module>
#       6     validate=(not args.no_validate),
#       7     timestamp=timestamp,
# ----> 8     meta=meta)
#
# ~/기타/경진대회/Detection/mmdetection/mmdet/apis/train.py in train_detector(model, dataset, cfg, distributed, validate, timestamp, meta)
#     121     else:
#     122         model = MMDataParallel(
# --> 123             model.cuda(cfg.gpu_ids[0]), device_ids=cfg.gpu_ids)
#     124
#     125     # build runner
#
# ~/anaconda3/envs/comet/lib/python3.7/site-packages/torch/nn/modules/module.py in cuda(self, device)
#     678             Module: self
#     679         """
# --> 680         return self._apply(lambda t: t.cuda(device))
#     681
#     682     def xpu(self: T, device: Optional[Union[int, device]] = None) -> T:
#
# ~/anaconda3/envs/comet/lib/python3.7/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     568     def _apply(self, fn):
#     569         for module in self.children():
# --> 570             module._apply(fn)
#     571
#     572         def compute_should_use_set_data(tensor, tensor_applied):
#
# ~/anaconda3/envs/comet/lib/python3.7/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     568     def _apply(self, fn):
#     569         for module in self.children():
# --> 570             module._apply(fn)
#     571
#     572         def compute_should_use_set_data(tensor, tensor_applied):
#
# ~/anaconda3/envs/comet/lib/python3.7/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     591             # `with torch.no_grad():`
#     592             with torch.no_grad():
# --> 593                 param_applied = fn(param)
#     594             should_use_set_data = compute_should_use_set_data(param, param_applied)
#     595             if should_use_set_data:
#
# ~/anaconda3/envs/comet/lib/python3.7/site-packages/torch/nn/modules/module.py in <lambda>(t)
#     678             Module: self
#     679         """
# --> 680         return self._apply(lambda t: t.cuda(device))
#     681
#     682     def xpu(self: T, device: Optional[Union[int, device]] = None) -> T:
#
# ~/anaconda3/envs/comet/lib/python3.7/site-packages/torch/cuda/__init__.py in _lazy_init()
#     212         # This function throws if there's a driver initialization error, no GPUs
#     213         # are found or any other error occurs
# --> 214         torch._C._cuda_init()
#     215         # Some of the queued calls may reentrantly call _lazy_init();
#     216         # we need to just return without initializing in that case.
#
# RuntimeError: Unexpected error from cudaGetDeviceCount(). Did you run some cuda functions before calling NumCudaDevices() that might have already set an error? Error 804: forward compatibility was attempted on non supported HW
